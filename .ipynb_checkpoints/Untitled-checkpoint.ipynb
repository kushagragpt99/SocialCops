# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import calendar
import datetime

# %%
x=float('nan')
x
# Out:
# nan

# %%
data1=pd.read_csv('CMO_MSP_Mandi.csv')
data2=pd.read_csv('Monthly_data_cmo.csv')
data2['Commodity']=data2['Commodity'].str.upper()
matrix2=data2.as_matrix()

# %%
data2.head()
# Out:
#          APMC      Commodity  Year  Month  arrivals_in_qtl  min_price  \
# 0  Ahmednagar          BAJRI  2015  April               79       1406
# 1  Ahmednagar          BAJRI  2016  April              106       1788
# 2  Ahmednagar  WHEAT(HUSKED)  2015  April             1253       1572
# 3  Ahmednagar  WHEAT(HUSKED)  2016  April              387       1750
# 4  Ahmednagar  SORGUM(JAWAR)  2015  April             3825       1600
#
#    max_price  modal_price     date district_name   state_name
# 0       1538         1463  2015-04    Ahmadnagar  Maharashtra
# 1       1925         1875  2016-04    Ahmadnagar  Maharashtra
# 2       1890         1731  2015-04    Ahmadnagar  Maharashtra
# 3       2220         1999  2016-04    Ahmadnagar  Maharashtra
# 4       2200         1900  2015-04    Ahmadnagar  Maharashtra

# %%
commodity_dict={}  #data from Monthly_data_cmo.csv in the form of a dict with keys as commodities and corresponding  
                    #values in the form of a numpy matrix
for x in data2['Commodity'].unique():
    commodity_dict[x]=np.zeros((1,data2.shape[1]))
for x in range(data2.shape[0]):
    commodity_dict[matrix2[x][1]]=np.vstack((commodity_dict[matrix2[x][1]], matrix2[x]))
for x in commodity_dict.keys():
    commodity_dict[x]=np.delete(commodity_dict[x], 0, axis=0)

# %%
commodity_dict
# Out:
# {'AMBA KOY': array([['Amarawati', 'AMBA KOY', 2016, 'July', 160, 4125, 5375, 4750,
#          '2016-07', 'Amaravathi', 'Maharashtra'],
#         ['Amarawati', 'AMBA KOY', 2016, 'June', 435, 3250, 4250, 3750,
#          '2016-06', 'Amaravathi', 'Maharashtra'],
#         ['Amarawati', 'AMBA KOY', 2016, 'May', 90, 1000, 2000, 1500,
#          '2016-05', 'Amaravathi', 'Maharashtra']], dtype=object),
#  'AMBAT CHUKA': array([['Kamthi', 'AMBAT CHUKA', 2016, 'August', 4, 1000, 1500, 1150,
#          '2016-08', 'Nagpur', 'Maharashtra'],
#         ['Nagpur', 'AMBAT CHUKA', 2016, 'August', 210, 1000, 1500, 1375,
#          '2016-08', 'Nagpur', 'Maharashtra'],
#         ['Nagpur', 'AMBAT CHUKA', 2016, 'June', 120, 800, 1000, 950,
#          '2016-06', 'Nagpur', 'Maharashtra'],
#         ['Nagpur', 'AMBAT CHUKA', 2015, 'October', 100, 1000, 1500, 1375,
#          '2015-10', 'Nagpur', 'Maharashtra'],
#         ['Nashik-Devlali', 'AMBAT CHUKA', 2016, 'August', 61, 166, 346,
#          264, '2016-08', 'Nasik', 'Maharashtra'],
#         ['Nashik-Devlali', 'AMBAT CHUKA', 2016, 'July', 17, 163, 413, 263,
#          '2016-07', 'Nasik', 'Maharashtra'],
#         ['Nashik-Devlali', 'AMBAT CHUKA', 2016, 'October', 40, 360, 647,
#          506, '2016-10', 'Nasik', 'Maharashtra'],
#         ['Nashik-Devlali', 'AMBAT CHUKA', 2016, 'September', 12, 150, 400,
#          300, '2016-09', 'Nasik', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'April', 29, 162, 1696, 196,
#          '2015-04', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'April', 17, 129, 1286, 193,
#          '2016-04', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'August', 17, 50, 1200, 125,
#          '2015-08', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'August', 39, 875, 950, 888,
#          '2016-08', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2014, 'December', 12, 180, 1440,
#          270, '2014-12', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'December', 17, 0, 1140, 0,
#          '2015-12', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'February', 10, 0, 1221, 0,
#          '2015-02', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'February', 4, 0, 750, 0,
#          '2016-02', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'January', 4, 0, 1350, 0,
#          '2015-01', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'July', 26, 200, 925, 400,
#          '2015-07', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'July', 50, 388, 1069, 388,
#          '2016-07', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'June', 4, 900, 1800, 1350,
#          '2015-06', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'June', 59, 33, 1844, 50,
#          '2016-06', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'March', 11, 0, 1300, 0,
#          '2015-03', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'May', 2, 0, 1500, 0,
#          '2015-05', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'May', 39, 0, 1326, 0,
#          '2016-05', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2014, 'November', 25, 133, 1433,
#          167, '2014-11', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'November', 37, 64, 887, 129,
#          '2015-11', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2014, 'October', 27, 109, 1255,
#          136, '2014-10', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'October', 29, 92, 1638, 115,
#          '2015-10', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'October', 34, 990, 990, 990,
#          '2016-10', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2014, 'September', 8, 0, 1650, 0,
#          '2014-09', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2015, 'September', 11, 100, 2010,
#          225, '2015-09', 'Pune', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'September', 26, 1031, 1031,
#          1031, '2016-09', 'Pune', 'Maharashtra'],
#         ['Kamthi', 'AMBAT CHUKA', 2016, 'November', 7, 1214, 1900, 1643,
#          '2016-11', 'Nagpur', 'Maharashtra'],
#         ['Pune-Manjri', 'AMBAT CHUKA', 2016, 'November', 35, 815, 939,
#          859, '2016-11', 'Pune', 'Maharashtra']], dtype=object),
#  'AMLA': array([['Jalgaon', 'AMLA', 2014, 'December', 179, 1200, 1732, 1468,
#          '2014-12', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2015, 'December', 184, 762, 1438, 1108,
#          '2015-12', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2015, 'February', 6, 1800, 2500, 2000,
#          '2015-02', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2016, 'February', 41, 1200, 1425, 1275,
#          '2016-02', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2015, 'January', 26, 1450, 1525, 1475,
#          '2015-01', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2016, 'January', 84, 1000, 1389, 1200,
#          '2016-01', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2014, 'November', 140, 1215, 1925, 1560,
#          '2014-11', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2015, 'November', 121, 1091, 1445, 1236,
#          '2015-11', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2014, 'October', 48, 883, 1767, 1383,
#          '2014-10', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2015, 'October', 196, 1006, 1647, 1329,
#          '2015-10', 'Jalgaon', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2014, 'September', 12, 1100, 1800, 1400,
#          '2014-09', 'Jalgaon', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2014, 'December', 1, 600, 3000, 1800,
#          '2014-12', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'December', 2, 1200, 2000, 1700,
#          '2015-12', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'February', 1, 1200, 2000, 1600,
#          '2015-02', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'January', 1, 600, 3000, 1800, '2015-01',
#          'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'March', 2, 600, 3000, 1800, '2015-03',
#          'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2014, 'November', 1, 1200, 2000, 1600,
#          '2014-11', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'November', 21, 800, 2000, 1500,
#          '2015-11', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2014, 'October', 8, 1129, 3214, 2171,
#          '2014-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'October', 26, 800, 2667, 1867,
#          '2015-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2016, 'October', 8, 1160, 2020, 1700,
#          '2016-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2015, 'September', 13, 1000, 2333, 1833,
#          '2015-09', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'AMLA', 2016, 'September', 3, 1800, 3000, 2500,
#          '2016-09', 'Nagpur', 'Maharashtra'],
#         ['Jalgaon', 'AMLA', 2016, 'November', 26, 1100, 2000, 1500,
#          '2016-11', 'Jalgaon', 'Maharashtra']], dtype=object),
#  'APPLE': array([['Rahuri', 'APPLE', 2016, ..., '2016-09', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Amarawati', 'APPLE', 2016, ..., '2016-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Amarawati-Fruit And Vegetables', 'APPLE', 2016, ..., '2016-04',
#          'Amaravathi', 'Maharashtra'],
#         ...,
#         ['Kolhapur', 'APPLE', 2016, ..., '2016-11', 'Kolhapur',
#          'Maharashtra'],
#         ['Mumbai-Fruit Market', 'APPLE', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra'],
#         ['Kalyan', 'APPLE', 2016, ..., '2016-11', 'Thane', 'Maharashtra']],
#        dtype=object),
#  'ARVI': array([['Mumbai', 'ARVI', 2015, 'April', 1550, 2547, 2867, 2707,
#          '2015-04', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'April', 1430, 1600, 1855, 1736,
#          '2016-04', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'August', 4400, 1074, 1432, 1311,
#          '2015-08', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'August', 1540, 1678, 2000, 1822,
#          '2016-08', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2014, 'December', 1600, 2480, 2800, 2640,
#          '2014-12', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'December', 2200, 929, 1294, 1135,
#          '2015-12', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'February', 1180, 2627, 2987, 2807,
#          '2015-02', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'February', 580, 960, 1280, 1140,
#          '2016-02', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'January', 480, 2675, 2925, 2800,
#          '2015-01', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'January', 1630, 908, 1269, 1108,
#          '2016-01', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'July', 7540, 1411, 1715, 1570,
#          '2015-07', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'July', 1950, 1556, 2067, 1833,
#          '2016-07', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'June', 7450, 1931, 2223, 2077,
#          '2015-06', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'June', 4790, 1565, 2000, 1794,
#          '2016-06', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'March', 1590, 2726, 3042, 2884,
#          '2015-03', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'March', 1370, 1100, 1583, 1400,
#          '2016-03', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'May', 3570, 2300, 2618, 2459, '2015-05',
#          'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'May', 1000, 1360, 1800, 1620, '2016-05',
#          'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2014, 'November', 3533, 2743, 3000, 2871,
#          '2014-11', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'November', 3410, 875, 1092, 985,
#          '2015-11', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2014, 'October', 2670, 2650, 2940, 2795,
#          '2014-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'October', 6560, 1012, 1269, 1165,
#          '2015-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'October', 2410, 1200, 1500, 1363,
#          '2016-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2014, 'September', 3200, 2591, 2991, 2791,
#          '2014-09', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2015, 'September', 6580, 870, 1213, 1096,
#          '2015-09', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'September', 2830, 1273, 1673, 1464,
#          '2016-09', 'Mumbai', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'April', 35, 1750, 2458, 2104, '2015-04',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'April', 94, 2873, 3167, 3007, '2016-04',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'August', 234, 1396, 2326, 1848, '2015-08',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'August', 199, 2489, 2932, 2712, '2016-08',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2014, 'December', 65, 1614, 2171, 1893,
#          '2014-12', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'December', 196, 2531, 2938, 2700,
#          '2015-12', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'February', 12, 1875, 3000, 2438,
#          '2015-02', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'February', 415, 2425, 2890, 2630,
#          '2016-02', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'January', 120, 2617, 3028, 2772,
#          '2016-01', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'July', 192, 1722, 2348, 2017, '2015-07',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'July', 162, 2794, 3267, 3017, '2016-07',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'June', 171, 2006, 2650, 2338, '2015-06',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'June', 266, 2721, 4504, 3075, '2016-06',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'March', 76, 1468, 2018, 1743, '2015-03',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'March', 190, 2600, 3145, 2870, '2016-03',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'May', 91, 1566, 2113, 1839, '2015-05',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'May', 265, 2933, 3190, 3033, '2016-05',
#          'Pune', 'Maharashtra'],
#         ['Pune-Pimpri', 'ARVI', 2016, 'May', 7, 2500, 3000, 2800,
#          '2016-05', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2014, 'November', 132, 1914, 2429, 2171,
#          '2014-11', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'November', 105, 2769, 3208, 2977,
#          '2015-11', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2014, 'October', 35, 1800, 2200, 2000, '2014-10',
#          'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'October', 185, 2082, 2906, 2629,
#          '2015-10', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'October', 114, 2325, 2890, 2650,
#          '2016-10', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2014, 'September', 37, 2000, 2500, 2250,
#          '2014-09', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2015, 'September', 178, 1785, 2750, 2260,
#          '2015-09', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'September', 109, 2344, 2856, 2622,
#          '2016-09', 'Pune', 'Maharashtra'],
#         ['Pune', 'ARVI', 2016, 'November', 118, 2459, 3018, 2771,
#          '2016-11', 'Pune', 'Maharashtra'],
#         ['Mumbai', 'ARVI', 2016, 'November', 1080, 1150, 1350, 1250,
#          '2016-11', 'Mumbai', 'Maharashtra']], dtype=object),
#  'ASTER': array([['Kalyan', 'ASTER', 2015, 'December', 15, 8000, 9600, 8860,
#          '2015-12', 'Thane', 'Maharashtra'],
#         ['Kalyan', 'ASTER', 2016, 'January', 15, 6200, 8200, 8020,
#          '2016-01', 'Thane', 'Maharashtra'],
#         ['Kalyan', 'ASTER', 2016, 'October', 3, 7000, 8000, 8000,
#          '2016-10', 'Thane', 'Maharashtra']], dtype=object),
#  'AWALA': array([['Amarawati', 'AWALA', 2014, 'December', 3, 3000, 3500, 3300,
#          '2014-12', 'Amaravathi', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2014, 'December', 203, 589, 850, 719,
#          '2014-12', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'December', 60, 609, 891, 755,
#          '2015-12', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'February', 21, 600, 775, 688,
#          '2015-02', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2016, 'February', 37, 1000, 1350, 1175,
#          '2016-02', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'January', 42, 550, 800, 675,
#          '2015-01', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2016, 'January', 91, 888, 1138, 1013,
#          '2016-01', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2014, 'November', 233, 653, 1000, 821,
#          '2014-11', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'November', 88, 614, 857, 736,
#          '2015-11', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2014, 'October', 147, 594, 1163, 881,
#          '2014-10', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'October', 84, 1000, 1419, 1184,
#          '2015-10', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2016, 'October', 57, 1011, 1344, 1178,
#          '2016-10', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2014, 'September', 41, 713, 988, 850,
#          '2014-09', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2015, 'September', 3, 1600, 1800, 1700,
#          '2015-09', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2016, 'September', 3, 1000, 1500, 1250,
#          '2016-09', 'Aurangabad', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2016, 'February', 9, 1500, 2000, 1800,
#          '2016-02', 'Chandrapur', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2015, 'January', 19, 1100, 1933, 1600,
#          '2015-01', 'Chandrapur', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2014, 'October', 51, 1055, 1736, 1323,
#          '2014-10', 'Chandrapur', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2016, 'October', 30, 1700, 2375, 2050,
#          '2016-10', 'Chandrapur', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2014, 'September', 28, 1400, 1820, 1640,
#          '2014-09', 'Chandrapur', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2015, 'September', 10, 1500, 2000, 1600,
#          '2015-09', 'Chandrapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2016, 'February', 81, 983, 2850, 1833,
#          '2016-02', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2016, 'January', 59, 825, 2500, 1550,
#          '2016-01', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2015, 'July', 18, 3100, 3300, 3200,
#          '2015-07', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2015, 'November', 11, 1500, 2150, 1875,
#          '2015-11', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2015, 'October', 42, 1300, 2600, 1900,
#          '2015-10', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2016, 'October', 16, 1000, 2500, 1700,
#          '2016-10', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2015, 'September', 3, 2000, 2200, 2100,
#          '2015-09', 'Kolhapur', 'Maharashtra'],
#         ['Nagpur', 'AWALA', 2015, 'November', 250, 600, 1000, 900,
#          '2015-11', 'Nagpur', 'Maharashtra'],
#         ['Osmanabad', 'AWALA', 2015, 'November', 7, 550, 1650, 1150,
#          '2015-11', 'Osmanabad', 'Maharashtra'],
#         ['Chandrapur', 'AWALA', 2016, 'November', 9, 1800, 2200, 2000,
#          '2016-11', 'Chandrapur', 'Maharashtra'],
#         ['Aurangabad', 'AWALA', 2016, 'November', 12, 800, 1133, 967,
#          '2016-11', 'Aurangabad', 'Maharashtra'],
#         ['Kolhapur', 'AWALA', 2016, 'November', 6, 1750, 1750, 1750,
#          '2016-11', 'Kolhapur', 'Maharashtra']], dtype=object),
#  'BAJRI': array([['Ahmednagar', 'BAJRI', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'BAJRI', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Akole', 'BAJRI', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Shevgaon', 'BAJRI', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shevgaon-Bodhegaon', 'BAJRI', 2016, ..., '2016-11',
#          'Ahmadnagar', 'Maharashtra'],
#         ['Shrigonda', 'BAJRI', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'BANANA': array([['Shrirampur', 'BANANA', 2015, ..., '2015-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Anajngaon Surji', 'BANANA', 2015, ..., '2015-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Anajngaon Surji', 'BANANA', 2016, ..., '2016-04', 'Amaravathi',
#          'Maharashtra'],
#         ...,
#         ['Kalyan', 'BANANA', 2016, ..., '2016-11', 'Thane', 'Maharashtra'],
#         ['Ulhasnagar', 'BANANA', 2016, ..., '2016-11', 'Thane',
#          'Maharashtra'],
#         ['Mumbai-Fruit Market', 'BANANA', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'BANANA(RAW)': array([['Pune', 'BANANA(RAW)', 2015, 'April', 190, 767, 933, 850,
#          '2015-04', 'Pune', 'Maharashtra'],
#         ['Pune', 'BANANA(RAW)', 2015, 'February', 40, 650, 950, 800,
#          '2015-02', 'Pune', 'Maharashtra'],
#         ['Pune', 'BANANA(RAW)', 2015, 'January', 2, 800, 1000, 900,
#          '2015-01', 'Pune', 'Maharashtra'],
#         ['Pune', 'BANANA(RAW)', 2015, 'March', 82, 729, 1029, 871,
#          '2015-03', 'Pune', 'Maharashtra'],
#         ['Pune', 'BANANA(RAW)', 2015, 'May', 38, 750, 950, 850, '2015-05',
#          'Pune', 'Maharashtra'],
#         ['Kalyan', 'BANANA(RAW)', 2015, 'December', 3, 2300, 2500, 2350,
#          '2015-12', 'Thane', 'Maharashtra']], dtype=object),
#  'BARU SEED': array([['Nanded', 'BARU SEED', 2016, 'June', 2, 4800, 4800, 4800,
#          '2016-06', 'Nanded', 'Maharashtra']], dtype=object),
#  'BATBATI': array([['Akola', 'BATBATI', 2016, 'August', 10, 2900, 2900, 2900,
#          '2016-08', 'Akola', 'Maharashtra'],
#         ['Akola', 'BATBATI', 2016, 'June', 40, 3050, 4000, 3525,
#          '2016-06', 'Akola', 'Maharashtra'],
#         ['Akola', 'BATBATI', 2016, 'May', 11, 3511, 4000, 3755, '2016-05',
#          'Akola', 'Maharashtra'],
#         ['Akola', 'BATBATI', 2016, 'October', 6, 3200, 3200, 3200,
#          '2016-10', 'Akola', 'Maharashtra'],
#         ['Akola', 'BATBATI', 2016, 'September', 10, 2600, 4200, 3400,
#          '2016-09', 'Akola', 'Maharashtra'],
#         ['Achalpur', 'BATBATI', 2016, 'July', 1, 3100, 3100, 3100,
#          '2016-07', 'Amaravathi', 'Maharashtra'],
#         ['Achalpur', 'BATBATI', 2014, 'November', 1, 4800, 4800, 4800,
#          '2014-11', 'Amaravathi', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'April', 72, 3667, 3833, 3750,
#          '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'April', 56, 4400, 4400, 4400,
#          '2016-04', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'August', 2, 4300, 4300, 4300,
#          '2015-08', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'August', 77, 4929, 4929, 4929,
#          '2016-08', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2014, 'December', 4, 3500, 3500, 3500,
#          '2014-12', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'February', 138, 3500, 3500, 3500,
#          '2015-02', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'February', 245, 4026, 4164, 4104,
#          '2016-02', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'January', 10, 3500, 3500, 3500,
#          '2015-01', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'January', 142, 4400, 4500, 4450,
#          '2016-01', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'July', 55, 4514, 4514, 4514,
#          '2016-07', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'June', 39, 4000, 4000, 4000,
#          '2015-06', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'June', 56, 3687, 3687, 3687,
#          '2016-06', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'March', 288, 3516, 3618, 3550,
#          '2015-03', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'March', 95, 4240, 4240, 4240,
#          '2016-03', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'May', 42, 4000, 4000, 4000, '2015-05',
#          'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'May', 96, 4267, 4267, 4267, '2016-05',
#          'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2014, 'October', 6, 3500, 3500, 3500,
#          '2014-10', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2015, 'October', 4, 4500, 4500, 4500,
#          '2015-10', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'October', 9, 4500, 4500, 4500,
#          '2016-10', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2014, 'September', 6, 3500, 3500, 3500,
#          '2014-09', 'Gadchiroli', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'September', 5, 3500, 3500, 3500,
#          '2016-09', 'Gadchiroli', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2014, 'December', 1, 4580, 4580, 4580,
#          '2014-12', 'Wasim', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2015, 'December', 4, 4850, 5328, 4850,
#          '2015-12', 'Wasim', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2015, 'February', 1, 4800, 4800, 4800,
#          '2015-02', 'Wasim', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2016, 'January', 2, 5700, 5700, 5700,
#          '2016-01', 'Wasim', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2015, 'March', 2, 4700, 4700, 4700,
#          '2015-03', 'Wasim', 'Maharashtra'],
#         ['Karanja', 'BATBATI', 2014, 'November', 4, 4935, 4935, 4935,
#          '2014-11', 'Wasim', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'April', 3, 4893, 4893, 4893,
#          '2016-04', 'Yewatmal', 'Maharashtra'],
#         ['Digras', 'BATBATI', 2016, 'August', 1, 2200, 2200, 2200,
#          '2016-08', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'August', 1, 4200, 4200, 4200,
#          '2016-08', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2015, 'December', 2, 5018, 5018, 5018,
#          '2015-12', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'July', 1, 5700, 5700, 5700, '2016-07',
#          'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'June', 2, 5300, 5300, 5300, '2016-06',
#          'Yewatmal', 'Maharashtra'],
#         ['Digras', 'BATBATI', 2016, 'March', 1, 3450, 3450, 3450,
#          '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'May', 1, 5100, 5100, 5100, '2016-05',
#          'Yewatmal', 'Maharashtra'],
#         ['Digras', 'BATBATI', 2014, 'November', 1, 1500, 0, 0, '2014-11',
#          'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2014, 'November', 1, 3900, 3900, 3900,
#          '2014-11', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2014, 'October', 1, 3925, 3925, 3925,
#          '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'October', 7, 5589, 5684, 5684,
#          '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Digras', 'BATBATI', 2015, 'September', 1, 4900, 4900, 4900,
#          '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Digras', 'BATBATI', 2016, 'September', 1, 5350, 5350, 5350,
#          '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2015, 'September', 4, 4193, 4193, 4193,
#          '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Pusad', 'BATBATI', 2016, 'September', 14, 4317, 5116, 5116,
#          '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Akola', 'BATBATI', 2016, 'November', 38, 3013, 3313, 3163,
#          '2016-11', 'Akola', 'Maharashtra'],
#         ['Aheri', 'BATBATI', 2016, 'November', 12, 4500, 4500, 4500,
#          '2016-11', 'Gadchiroli', 'Maharashtra']], dtype=object),
#  'BEDANA': array([['Sangali', 'BEDANA', 2015, 'April', 63139, 9750, 24550, 16592,
#          '2015-04', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'April', 35758, 10000, 17650, 14020,
#          '2016-04', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'April', 101815, 8695, 15868, 11934,
#          '2015-04', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'April', 82922, 6303, 13200, 7761,
#          '2016-04', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'August', 54658, 9636, 21509, 14000,
#          '2015-08', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'August', 45415, 9500, 17438, 13063,
#          '2016-08', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'August', 80639, 6262, 14500, 7869,
#          '2015-08', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'August', 76836, 6227, 12436, 7997,
#          '2016-08', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2014, 'December', 15620, 11720, 26920,
#          18400, '2014-12', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'December', 30023, 9000, 18950, 12400,
#          '2015-12', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2014, 'December', 23321, 12791, 18245,
#          15721, '2014-12', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'December', 44362, 5713, 12463, 7300,
#          '2015-12', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'February', 39242, 10222, 25400,
#          16722, '2015-02', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'February', 58394, 10000, 19736,
#          14364, '2016-02', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'February', 40756, 11963, 18067,
#          14998, '2015-02', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'February', 77819, 6335, 13548, 7919,
#          '2016-02', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'January', 18556, 11000, 30040, 19050,
#          '2015-01', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'January', 33725, 9091, 17336, 13391,
#          '2016-01', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'January', 20845, 13283, 19449, 16131,
#          '2015-01', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'January', 39499, 5912, 12194, 7064,
#          '2016-01', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'July', 53608, 9182, 20936, 14591,
#          '2015-07', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'July', 22959, 10000, 16420, 13400,
#          '2016-07', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'July', 70018, 6353, 14328, 8026,
#          '2015-07', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'July', 35755, 6414, 12362, 7838,
#          '2016-07', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'June', 46829, 9500, 22525, 15050,
#          '2015-06', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'June', 33892, 10000, 15989, 13167,
#          '2016-06', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'June', 75578, 6506, 14858, 8583,
#          '2015-06', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'June', 59214, 6612, 12836, 7970,
#          '2016-06', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'March', 38183, 9875, 24175, 17025,
#          '2015-03', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'March', 74473, 10000, 18793, 14667,
#          '2016-03', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'March', 104737, 11843, 17751, 14626,
#          '2015-03', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'March', 114648, 6620, 15013, 8084,
#          '2016-03', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'May', 33931, 10000, 22613, 16163,
#          '2015-05', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'May', 28643, 9700, 15440, 12200,
#          '2016-05', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'May', 66172, 6892, 14539, 10475,
#          '2015-05', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'May', 58685, 6529, 13102, 7864,
#          '2016-05', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2014, 'November', 12612, 11500, 26925,
#          19150, '2014-11', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2014, 'November', 8917, 12600, 18673, 15733,
#          '2014-11', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'November', 4218, 5833, 14000, 7500,
#          '2015-11', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2014, 'October', 5943, 12500, 27800, 20500,
#          '2014-10', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'October', 69672, 9700, 22940, 14850,
#          '2015-10', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'October', 19635, 9000, 15850, 12125,
#          '2016-10', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2014, 'October', 6886, 11800, 17247, 14533,
#          '2014-10', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'October', 75601, 6334, 15000, 7966,
#          '2015-10', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'October', 31116, 6221, 12000, 7800,
#          '2016-10', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2014, 'September', 34646, 14286, 29600,
#          21786, '2014-09', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2015, 'September', 32260, 9375, 21900,
#          14925, '2015-09', 'Sangli', 'Maharashtra'],
#         ['Sangali', 'BEDANA', 2016, 'September', 46110, 9889, 16389,
#          13089, '2016-09', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2014, 'September', 33591, 12806, 20214,
#          15497, '2014-09', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2015, 'September', 65514, 6052, 15085, 8027,
#          '2015-09', 'Sangli', 'Maharashtra'],
#         ['Tasgaon', 'BEDANA', 2016, 'September', 75485, 6183, 32470, 7864,
#          '2016-09', 'Sangli', 'Maharashtra'],
#         ['Pandharpur', 'BEDANA', 2015, 'April', 10879, 3167, 24567, 16333,
#          '2015-04', 'Solapur', 'Maharashtra'],
#         ['Pandharpur', 'BEDANA', 2015, 'March', 12770, 4167, 25500, 16833,
#          '2015-03', 'Solapur', 'Maharashtra']], dtype=object),
#  'BEET ROOT': array([['Rahata', 'BEET ROOT', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BEET ROOT', 2015, ..., '2015-08', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BEET ROOT', 2016, ..., '2016-08', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Junnar-Otur', 'BEET ROOT', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra'],
#         ['Rahata', 'BEET ROOT', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Mumbai', 'BEET ROOT', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'BETELNUTS': array([['Mumbai', 'BETELNUTS', 2015, 'April', 1351, 27429, 30000, 28714,
#          '2015-04', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'April', 898, 28000, 30000, 29000,
#          '2016-04', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'August', 726, 28000, 31000, 29500,
#          '2015-08', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'August', 89, 24000, 28000, 26000,
#          '2016-08', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2014, 'December', 1687, 28385, 31769,
#          30077, '2014-12', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'December', 476, 31875, 34125,
#          33000, '2015-12', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'February', 1805, 28909, 32000,
#          30455, '2015-02', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'February', 924, 28000, 30000,
#          29000, '2016-02', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'January', 1834, 26958, 30458,
#          28708, '2015-01', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'January', 280, 30167, 32000, 31083,
#          '2016-01', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'July', 1193, 28650, 32300, 30475,
#          '2015-07', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'July', 89, 24000, 28000, 26000,
#          '2016-07', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'June', 816, 32426, 36163, 34295,
#          '2015-06', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'June', 144, 25333, 28667, 27000,
#          '2016-06', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'March', 1521, 28500, 31300, 29900,
#          '2015-03', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'March', 460, 28000, 30000, 29000,
#          '2016-03', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'May', 1116, 30952, 34952, 32952,
#          '2015-05', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'May', 830, 28000, 30000, 29000,
#          '2016-05', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2014, 'November', 1313, 30126, 32832,
#          31479, '2014-11', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2014, 'October', 1372, 29684, 36737,
#          33211, '2014-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'October', 88, 28000, 32000, 30000,
#          '2015-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'October', 312, 24000, 28000, 26000,
#          '2016-10', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2014, 'September', 1465, 30095, 35619,
#          32857, '2014-09', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2015, 'September', 338, 28000, 31833,
#          29917, '2015-09', 'Mumbai', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'September', 22, 24000, 28000,
#          26000, '2016-09', 'Mumbai', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'April', 780, 1500, 2500, 2000,
#          '2016-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'February', 7080, 1240, 1901, 1460,
#          '2016-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'January', 3000, 1, 3, 2, '2016-01',
#          'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'March', 9660, 1428, 2264, 1836,
#          '2016-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'May', 630, 1500, 2500, 2000,
#          '2016-05', 'Raigad', 'Maharashtra'],
#         ['Mumbai', 'BETELNUTS', 2016, 'November', 1321, 22285, 25985,
#          24131, '2016-11', 'Mumbai', 'Maharashtra']], dtype=object),
#  'BHAGAR/VARI': array([['Akole', 'BHAGAR/VARI', 2014, 'December', 59, 2000, 2600, 2400,
#          '2014-12', 'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'BHAGAR/VARI', 2015, 'January', 5, 2700, 3000, 2850,
#          '2015-01', 'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'BHAGAR/VARI', 2016, 'January', 20, 2550, 3200, 3000,
#          '2016-01', 'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'BHAGAR/VARI', 2014, 'November', 8, 2000, 2600, 2400,
#          '2014-11', 'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'BHAGAR/VARI', 2014, 'October', 4, 2000, 2600, 2400,
#          '2014-10', 'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'BHAGAR/VARI', 2014, 'September', 2, 2000, 3000, 2500,
#          '2014-09', 'Ahmadnagar', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2016, 'August', 1, 2000, 2000, 2000,
#          '2016-08', 'Beed', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2015, 'December', 2, 2101, 2101, 2101,
#          '2015-12', 'Beed', 'Maharashtra'],
#         ['Gevrai', 'BHAGAR/VARI', 2015, 'February', 1, 1300, 1300, 1300,
#          '2015-02', 'Beed', 'Maharashtra'],
#         ['Gevrai', 'BHAGAR/VARI', 2015, 'January', 3, 1551, 1551, 1551,
#          '2015-01', 'Beed', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2016, 'January', 2, 2202, 2202, 2202,
#          '2016-01', 'Beed', 'Maharashtra'],
#         ['Gevrai', 'BHAGAR/VARI', 2016, 'June', 1, 2000, 2000, 2000,
#          '2016-06', 'Beed', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2016, 'May', 1, 2301, 2301, 2301,
#          '2016-05', 'Beed', 'Maharashtra'],
#         ['Gevrai', 'BHAGAR/VARI', 2014, 'October', 1, 1500, 1500, 1500,
#          '2014-10', 'Beed', 'Maharashtra'],
#         ['Gevrai', 'BHAGAR/VARI', 2015, 'October', 5, 2354, 2400, 2400,
#          '2015-10', 'Beed', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2016, 'October', 2, 1466, 1801, 1801,
#          '2016-10', 'Beed', 'Maharashtra'],
#         ['Kej', 'BHAGAR/VARI', 2016, 'September', 1, 1901, 1901, 1901,
#          '2016-09', 'Beed', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'August', 139, 1591, 1775, 1683,
#          '2016-08', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'February', 45, 1500, 1700,
#          1625, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'January', 147, 1225, 1308,
#          1267, '2016-01', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'July', 94, 1503, 1700, 1608,
#          '2016-07', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'June', 69, 1512, 1619, 1567,
#          '2016-06', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'March', 56, 1530, 1700, 1650,
#          '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'October', 205, 1515, 1647,
#          1579, '2016-10', 'Nandurbar', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'September', 162, 1600, 1739,
#          1670, '2016-09', 'Nandurbar', 'Maharashtra'],
#         ['Devala', 'BHAGAR/VARI', 2016, 'October', 1, 4000, 4000, 4000,
#          '2016-10', 'Nasik', 'Maharashtra'],
#         ['Pune', 'BHAGAR/VARI', 2016, 'June', 89, 3000, 4000, 3500,
#          '2016-06', 'Pune', 'Maharashtra'],
#         ['Shahapur', 'BHAGAR/VARI', 2015, 'December', 36, 2689, 2933,
#          2811, '2015-12', 'Thane', 'Maharashtra'],
#         ['Shahapur', 'BHAGAR/VARI', 2015, 'November', 4, 2800, 3000, 2900,
#          '2015-11', 'Thane', 'Maharashtra'],
#         ['Dhadgaon', 'BHAGAR/VARI', 2016, 'November', 80, 1413, 1500,
#          1456, '2016-11', 'Nandurbar', 'Maharashtra']], dtype=object),
#  'BIJLI': array([['Pune', 'BIJLI', 2014, 'September', 183, 11000, 15500, 13250,
#          '2014-09', 'Pune', 'Maharashtra'],
#         ['Kalyan', 'BIJLI', 2016, 'January', 21, 4286, 5286, 5114,
#          '2016-01', 'Thane', 'Maharashtra'],
#         ['Kalyan', 'BIJLI', 2015, 'March', 3, 2000, 2200, 2100, '2015-03',
#          'Thane', 'Maharashtra']], dtype=object),
#  'BITTER GOURD': array([['Ahmednagar', 'BITTER GOURD', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BITTER GOURD', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BITTER GOURD', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Rahata', 'BITTER GOURD', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahuri', 'BITTER GOURD', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Mumbai', 'BITTER GOURD', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'BLACK GRAM': array([['Ahmednagar', 'BLACK GRAM', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'BLACK GRAM', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'BLACK GRAM', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Ahmednagar', 'BLACK GRAM', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Pathardi', 'BLACK GRAM', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrigonda', 'BLACK GRAM', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'BOR': array([['Rahata', 'BOR', 2014, ..., '2014-12', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BOR', 2015, ..., '2015-12', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahuri', 'BOR', 2015, ..., '2015-12', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Shrirampur', 'BOR', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Nashik', 'BOR', 2016, ..., '2016-11', 'Nasik', 'Maharashtra'],
#         ['Kolhapur', 'BOR', 2016, ..., '2016-11', 'Kolhapur',
#          'Maharashtra']], dtype=object),
#  'BOTTLE GOURD': array([['Rahata', 'BOTTLE GOURD', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BOTTLE GOURD', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'BOTTLE GOURD', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Rahata', 'BOTTLE GOURD', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahuri', 'BOTTLE GOURD', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Mumbai', 'BOTTLE GOURD', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'BRINJAL': array([['Ahmednagar', 'BRINJAL', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BRINJAL', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'BRINJAL', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Rahata', 'BRINJAL', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahuri', 'BRINJAL', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Mumbai', 'BRINJAL', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'BUFFALO': array([['Daryapur', 'BUFFALO', 2015, 'December', 19, 23000, 28500, 25500,
#          '2015-12', 'Amaravathi', 'Maharashtra'],
#         ['Daryapur', 'BUFFALO', 2015, 'July', 21, 25000, 30000, 26000,
#          '2015-07', 'Amaravathi', 'Maharashtra'],
#         ['Khamgaon', 'BUFFALO', 2016, 'April', 112, 20000, 68000, 45750,
#          '2016-04', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BUFFALO', 2016, 'August', 304, 20000, 50000, 35000,
#          '2016-08', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BUFFALO', 2014, 'December', 282, 12500, 45000,
#          28750, '2014-12', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BUFFALO', 2015, 'January', 184, 10000, 40000, 25000,
#          '2015-01', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BUFFALO', 2016, 'October', 146, 20000, 56000, 41500,
#          '2016-10', 'Buldhana', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BUFFALO', 2016, 'August', 180, 6000, 40000,
#          35000, '2016-08', 'Pune', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BUFFALO', 2016, 'June', 42, 15000, 40000,
#          35000, '2016-06', 'Pune', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BUFFALO', 2016, 'October', 66, 17000, 25000,
#          23000, '2016-10', 'Pune', 'Maharashtra'],
#         ['Palus', 'BUFFALO', 2016, 'February', 38, 14000, 45500, 35100,
#          '2016-02', 'Sangli', 'Maharashtra'],
#         ['Palus', 'BUFFALO', 2016, 'September', 54, 18000, 45500, 31500,
#          '2016-09', 'Sangli', 'Maharashtra'],
#         ['Akluj', 'BUFFALO', 2016, 'March', 21, 4500, 6000, 6000,
#          '2016-03', 'Solapur', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BUFFALO', 2016, 'November', 91, 15000, 25000,
#          22000, '2016-11', 'Pune', 'Maharashtra']], dtype=object),
#  'BULLACK': array([['Daryapur', 'BULLACK', 2015, 'November', 39, 25000, 32000, 29000,
#          '2015-11', 'Amaravathi', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2016, 'April', 221, 8000, 25000, 18000,
#          '2016-04', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2015, 'December', 251, 5000, 20000, 12500,
#          '2015-12', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2016, 'February', 221, 10000, 25000,
#          21500, '2016-02', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2015, 'January', 176, 10000, 20000, 15000,
#          '2015-01', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2016, 'January', 449, 8500, 20000, 15500,
#          '2016-01', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2016, 'June', 202, 10000, 20000, 18000,
#          '2016-06', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2014, 'October', 66, 5000, 30000, 17500,
#          '2014-10', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2016, 'October', 128, 10000, 25000, 19250,
#          '2016-10', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'BULLACK', 2015, 'September', 89, 10000, 20000,
#          16200, '2015-09', 'Buldhana', 'Maharashtra'],
#         ['Korpana', 'BULLACK', 2016, 'January', 47, 15000, 25000, 20000,
#          '2016-01', 'Chandrapur', 'Maharashtra'],
#         ['Jintur', 'BULLACK', 2016, 'January', 4, 1575, 1575, 1575,
#          '2016-01', 'Parbhani', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BULLACK', 2016, 'August', 180, 5000, 30000,
#          25000, '2016-08', 'Pune', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BULLACK', 2016, 'June', 1224, 12500, 22500,
#          21000, '2016-06', 'Pune', 'Maharashtra'],
#         ['Junnar (Bhlhe)', 'BULLACK', 2016, 'May', 850, 10000, 20000,
#          18000, '2016-05', 'Pune', 'Maharashtra'],
#         ['Malegaon (Washim)', 'BULLACK', 2016, 'February', 23, 8000,
#          40000, 27000, '2016-02', 'Wasim', 'Maharashtra']], dtype=object),
#  'BULLOCK HEART': array([['Amarawati', 'BULLOCK HEART', 2016, 'March', 6, 2000, 3000, 2500,
#          '2016-03', 'Amaravathi', 'Maharashtra'],
#         ['Jalgaon', 'BULLOCK HEART', 2015, 'April', 6, 2500, 4000, 3000,
#          '2015-04', 'Jalgaon', 'Maharashtra'],
#         ['Kolhapur', 'BULLOCK HEART', 2015, 'December', 10, 2000, 15000,
#          5000, '2015-12', 'Kolhapur', 'Maharashtra']], dtype=object),
# ...
#          '2015-04', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'April', 130, 13264, 16575, 14920,
#          '2016-04', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'August', 81, 11917, 15329, 13623,
#          '2016-08', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2015, 'December', 31, 9894, 11511,
#          10703, '2015-12', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'February', 755, 12845, 14317,
#          13581, '2016-02', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'January', 96, 10910, 13090,
#          12000, '2016-01', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2015, 'July', 120, 7875, 10350, 9112,
#          '2015-07', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'July', 30, 10000, 12500, 11250,
#          '2016-07', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2015, 'June', 190, 7271, 10296, 8859,
#          '2015-06', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'June', 63, 12795, 15783, 14289,
#          '2016-06', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'March', 130, 14488, 16113, 15301,
#          '2016-03', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'May', 311, 14356, 17244, 15800,
#          '2016-05', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2015, 'September', 115, 7500, 9300,
#          8400, '2015-09', 'Akola', 'Maharashtra'],
#         ['Akot', 'THYMOL/LOVAGE', 2016, 'September', 45, 13000, 15250,
#          14125, '2016-09', 'Akola', 'Maharashtra'],
#         ['Daryapur', 'THYMOL/LOVAGE', 2015, 'July', 6, 7500, 7500, 7500,
#          '2015-07', 'Amaravathi', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2015, 'April', 37, 10450,
#          10827, 10629, '2015-04', 'Aurangabad', 'Maharashtra'],
#         ['Vaijapur', 'THYMOL/LOVAGE', 2016, 'August', 1, 12001, 12001,
#          12001, '2016-08', 'Aurangabad', 'Maharashtra'],
#         ['Vaijapur', 'THYMOL/LOVAGE', 2015, 'December', 1, 5500, 5500,
#          5500, '2015-12', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2015, 'February', 10, 8500,
#          9000, 8850, '2015-02', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2016, 'February', 25, 11167,
#          12585, 12167, '2016-02', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2016, 'January', 10, 10400,
#          12000, 11980, '2016-01', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2015, 'June', 45, 10918, 11246,
#          11017, '2015-06', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2015, 'March', 58, 9128, 9471,
#          9398, '2015-03', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2016, 'March', 15, 14150,
#          15150, 14800, '2016-03', 'Aurangabad', 'Maharashtra'],
#         ['Lasur Station', 'THYMOL/LOVAGE', 2015, 'May', 18, 9688, 10013,
#          9888, '2015-05', 'Aurangabad', 'Maharashtra'],
#         ['Vaijapur', 'THYMOL/LOVAGE', 2016, 'September', 1, 10000, 10000,
#          10000, '2016-09', 'Aurangabad', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'April', 885, 7142, 11230,
#          9249, '2015-04', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'April', 230, 10175, 16053,
#          13665, '2016-04', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'August', 49, 7531, 9028, 8280,
#          '2015-08', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'August', 8, 11065, 11688,
#          11065, '2016-08', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2014, 'December', 6, 6369, 6369,
#          6369, '2014-12', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'December', 9, 8638, 9200,
#          9200, '2015-12', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'February', 841, 8175, 10763,
#          9429, '2015-02', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'February', 774, 10021, 14670,
#          12345, '2016-02', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'THYMOL/LOVAGE', 2016, 'January', 22, 12250, 12250,
#          12250, '2016-01', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'January', 45, 7006, 8394,
#          7950, '2015-01', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'January', 157, 9703, 12050,
#          11392, '2016-01', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'July', 83, 8036, 14084, 9103,
#          '2015-07', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'July', 4, 11417, 11417, 11417,
#          '2016-07', 'Buldhana', 'Maharashtra'],
#         ['Khamgaon', 'THYMOL/LOVAGE', 2015, 'June', 1, 7000, 7000, 7000,
#          '2015-06', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'June', 258, 7915, 10829, 9485,
#          '2015-06', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'June', 56, 13413, 14020,
#          13687, '2016-06', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'March', 672, 7069, 9510, 8290,
#          '2015-03', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'March', 391, 10000, 16013,
#          13461, '2016-03', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'May', 436, 8278, 11473, 9914,
#          '2015-05', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'May', 253, 10607, 15743,
#          14537, '2016-05', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2014, 'November', 22, 6229, 6264,
#          6229, '2014-11', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'November', 10, 10096, 10246,
#          10171, '2015-11', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2014, 'October', 25, 7175, 7488,
#          7300, '2014-10', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'October', 17, 9359, 14371,
#          9615, '2015-10', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'October', 9, 11350, 12800,
#          12350, '2016-10', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2014, 'September', 32, 6942, 7889,
#          7837, '2014-09', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2015, 'September', 45, 7750, 8542,
#          8104, '2015-09', 'Buldhana', 'Maharashtra'],
#         ['Shegaon', 'THYMOL/LOVAGE', 2016, 'September', 18, 9943, 9943,
#          9943, '2016-09', 'Buldhana', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2015, 'April', 11, 6600, 8000,
#          7300, '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2014, 'December', 643, 9213, 12832,
#          11139, '2014-12', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2015, 'December', 1490, 11813,
#          14442, 13381, '2015-12', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2015, 'February', 199, 9441, 12555,
#          11508, '2015-02', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2016, 'February', 363, 12293,
#          14629, 13629, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2015, 'January', 919, 9763, 14432,
#          12331, '2015-01', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2016, 'January', 2000, 10900,
#          14184, 12659, '2016-01', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2015, 'March', 4, 10000, 10000,
#          10000, '2015-03', 'Nandurbar', 'Maharashtra'],
#         ['Nandurbar', 'THYMOL/LOVAGE', 2016, 'March', 1, 17700, 17700,
#          17700, '2016-03', 'Nandurbar', 'Maharashtra']], dtype=object),
#  'TOMATO': array([['Ahmednagar', 'TOMATO', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'TOMATO', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'TOMATO', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Rahuri', 'TOMATO', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Mumbai', 'TOMATO', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra'],
#         ['Sangamner', 'TOMATO', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'TULJAPURI': array([['Pune', 'TULJAPURI', 2014, 'September', 103, 3500, 6250, 4875,
#          '2014-09', 'Pune', 'Maharashtra']], dtype=object),
#  'TURMERIC': array([['Sironcha', 'TURMERIC', 2016, ..., '2016-05', 'Gadchiroli',
#          'Maharashtra'],
#         ['Akhadabalapur', 'TURMERIC', 2015, ..., '2015-04', 'Hingoli',
#          'Maharashtra'],
#         ['Akhadabalapur', 'TURMERIC', 2016, ..., '2016-04', 'Hingoli',
#          'Maharashtra'],
#         ...,
#         ['Loha', 'TURMERIC', 2016, ..., '2016-11', 'Nanded',
#          'Maharashtra'],
#         ['Pune', 'TURMERIC', 2016, ..., '2016-11', 'Pune', 'Maharashtra'],
#         ['Mumbai', 'TURMERIC', 2016, ..., '2016-11', 'Mumbai',
#          'Maharashtra']], dtype=object),
#  'WAL BHAJI': array([['Aurangabad', 'WAL BHAJI', 2015, ..., '2015-04', 'Aurangabad',
#          'Maharashtra'],
#         ['Aurangabad', 'WAL BHAJI', 2016, ..., '2016-04', 'Aurangabad',
#          'Maharashtra'],
#         ['Aurangabad', 'WAL BHAJI', 2015, ..., '2015-08', 'Aurangabad',
#          'Maharashtra'],
#         ...,
#         ['Aurangabad', 'WAL BHAJI', 2016, ..., '2016-11', 'Aurangabad',
#          'Maharashtra'],
#         ['Pune', 'WAL BHAJI', 2016, ..., '2016-11', 'Pune', 'Maharashtra'],
#         ['Pune-Moshi', 'WAL BHAJI', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra']], dtype=object),
#  'WAL PAPDI': array([['Shrirampur', 'WAL PAPDI', 2015, ..., '2015-02', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'WAL PAPDI', 2015, ..., '2015-01', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'WAL PAPDI', 2016, ..., '2016-01', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Pune-Pimpri', 'WAL PAPDI', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra'],
#         ['Pune-Moshi', 'WAL PAPDI', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra'],
#         ['Khed-Chakan', 'WAL PAPDI', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra']], dtype=object),
#  'WALVAD': array([['Rahata', 'WALVAD', 2015, ..., '2015-08', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'WALVAD', 2016, ..., '2016-08', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Rahata', 'WALVAD', 2014, ..., '2014-12', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Pune-Moshi', 'WALVAD', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra'],
#         ['Khed-Chakan', 'WALVAD', 2016, ..., '2016-11', 'Pune',
#          'Maharashtra'],
#         ['Rahata', 'WALVAD', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'WATER MELON': array([['Shrirampur', 'WATER MELON', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'WATER MELON', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shrirampur', 'WATER MELON', 2015, ..., '2015-08', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Shrirampur', 'WATER MELON', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Kolhapur', 'WATER MELON', 2016, ..., '2016-11', 'Kolhapur',
#          'Maharashtra'],
#         ['Mumbai-Fruit Market', 'WATER MELON', 2016, ..., '2016-11',
#          'Mumbai', 'Maharashtra']], dtype=object),
#  'WHEAT(HUSKED)': array([['Ahmednagar', 'WHEAT(HUSKED)', 2015, ..., '2015-04',
#          'Ahmadnagar', 'Maharashtra'],
#         ['Ahmednagar', 'WHEAT(HUSKED)', 2016, ..., '2016-04',
#          'Ahmadnagar', 'Maharashtra'],
#         ['Akole', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Shevgaon', 'WHEAT(HUSKED)', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Shevgaon-Bodhegaon', 'WHEAT(HUSKED)', 2016, ..., '2016-11',
#          'Ahmadnagar', 'Maharashtra'],
#         ['Shrigonda', 'WHEAT(HUSKED)', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'WHEAT(UNHUSKED)': array([['Ausa', 'WHEAT(UNHUSKED)', 2014, ..., '2014-12', 'Latur',
#          'Maharashtra'],
#         ['Murum', 'WHEAT(UNHUSKED)', 2015, ..., '2015-04', 'Osmanabad',
#          'Maharashtra'],
#         ['Tuljapur', 'WHEAT(UNHUSKED)', 2015, ..., '2015-04', 'Osmanabad',
#          'Maharashtra'],
#         ...,
#         ['Sangli-Miraj', 'WHEAT(UNHUSKED)', 2016, ..., '2016-11',
#          'Sangli', 'Maharashtra'],
#         ['Solapur', 'WHEAT(UNHUSKED)', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra'],
#         ['Mangalwedha', 'WHEAT(UNHUSKED)', 2016, ..., '2016-11',
#          'Solapur', 'Maharashtra']], dtype=object),
#  'WOOD APPLE': array([['Kolhapur', 'WOOD APPLE', 2015, 'December', 92, 500, 2500, 1500,
#          '2015-12', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'WOOD APPLE', 2015, 'November', 11, 2000, 2500, 2250,
#          '2015-11', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'WOOD APPLE', 2016, 'October', 34, 2000, 3250, 2625,
#          '2016-10', 'Kolhapur', 'Maharashtra'],
#         ['Kolhapur', 'WOOD APPLE', 2015, 'September', 11, 800, 2500, 1400,
#          '2015-09', 'Kolhapur', 'Maharashtra']], dtype=object),
#  'ZENDU': array([['Aurangabad', 'ZENDU', 2015, 'November', 504, 1900, 5500, 3700,
#          '2015-11', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'ZENDU', 2014, 'October', 1277, 2300, 3400, 2850,
#          '2014-10', 'Aurangabad', 'Maharashtra'],
#         ['Aurangabad', 'ZENDU', 2016, 'October', 8927, 1440, 2460, 1950,
#          '2016-10', 'Aurangabad', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2014, 'December', 1, 800, 1600, 1200,
#          '2014-12', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2014, 'November', 3, 1000, 2067, 1533,
#          '2014-11', 'Nagpur', 'Maharashtra'],
#         ['Ramtek', 'ZENDU', 2015, 'November', 15, 4500, 5500, 5000,
#          '2015-11', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2014, 'October', 18, 2120, 4400, 3260,
#          '2014-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2015, 'October', 5, 3000, 5000, 4100,
#          '2015-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2016, 'October', 44, 950, 1586, 1364,
#          '2016-10', 'Nagpur', 'Maharashtra'],
#         ['Ramtek', 'ZENDU', 2015, 'October', 9, 2000, 3000, 2500,
#          '2015-10', 'Nagpur', 'Maharashtra'],
#         ['Ramtek', 'ZENDU', 2016, 'October', 39, 1133, 1333, 1233,
#          '2016-10', 'Nagpur', 'Maharashtra'],
#         ['Kamthi', 'ZENDU', 2016, 'September', 2, 1500, 2500, 2100,
#          '2016-09', 'Nagpur', 'Maharashtra'],
#         ['Chandvad', 'ZENDU', 2015, 'October', 868, 833, 3975, 1989,
#          '2015-10', 'Nasik', 'Maharashtra'],
#         ['Chandvad', 'ZENDU', 2016, 'October', 3016, 507, 2372, 1368,
#          '2016-10', 'Nasik', 'Maharashtra'],
#         ['Chandvad', 'ZENDU', 2016, 'September', 193, 300, 1105, 650,
#          '2016-09', 'Nasik', 'Maharashtra'],
#         ['Pune-Manjri', 'ZENDU', 2016, 'October', 1, 3000, 3000, 3000,
#          '2016-10', 'Pune', 'Maharashtra'],
#         ['Pune', 'ZENDU', 2014, 'September', 1386, 3250, 6750, 5000,
#          '2014-09', 'Pune', 'Maharashtra'],
#         ['Kalyan', 'ZENDU', 2015, 'December', 15, 5000, 6000, 5680,
#          '2015-12', 'Thane', 'Maharashtra'],
#         ['Kalyan', 'ZENDU', 2016, 'January', 27, 3667, 5111, 4711,
#          '2016-01', 'Thane', 'Maharashtra'],
#         ['Kalyan', 'ZENDU', 2015, 'July', 3, 2500, 3000, 3000, '2015-07',
#          'Thane', 'Maharashtra'],
#         ['Kalyan', 'ZENDU', 2015, 'March', 3, 3000, 4000, 3500, '2015-03',
#          'Thane', 'Maharashtra'],
#         ['Kalyan', 'ZENDU', 2016, 'October', 3, 2000, 3000, 3000,
#          '2016-10', 'Thane', 'Maharashtra']], dtype=object)}

# %%
APMC_dict={}     #data from Monthly_data_cmo.csv in the form of a dict with keys as APMCs and corresponding  
                #values in the form of a numpy matrix
for x in data2['APMC'].unique():
    APMC_dict[x]=np.zeros((1,data2.shape[1]))
for x in range(data2.shape[0]):
    APMC_dict[matrix2[x][0]]=np.vstack((APMC_dict[matrix2[x][0]], matrix2[x]))
for x in APMC_dict.keys():
    APMC_dict[x]=np.delete(APMC_dict[x], 0, axis=0)

# %%
APMC_dict
# Out:
# {'Aamgaon': array([['Aamgaon', 'PADDY-UNHUSKED', 2015, 'April', 2728, 1441, 1442,
#          1412, '2015-04', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'April', 1481, 1630, 1684,
#          1657, '2016-04', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'August', 5046, 1520, 1603,
#          1562, '2015-08', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'August', 1819, 1598, 1713,
#          1667, '2016-08', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2014, 'December', 14608, 1481, 1554,
#          1518, '2014-12', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'December', 14645, 1529, 1600,
#          1564, '2015-12', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'February', 7674, 1481, 1530,
#          1505, '2015-02', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'February', 6883, 1526, 1591,
#          1558, '2016-02', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'January', 16775, 1505, 1562,
#          1533, '2015-01', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'January', 9539, 1489, 1558,
#          1523, '2016-01', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'July', 5499, 1459, 1555,
#          1510, '2015-07', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'July', 1805, 1626, 1752,
#          1693, '2016-07', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'June', 9312, 1348, 1369,
#          1339, '2015-06', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'June', 10278, 1536, 1670,
#          1604, '2016-06', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'March', 5294, 1459, 1445,
#          1419, '2015-03', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'March', 2908, 1602, 1664,
#          1633, '2016-03', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'May', 3688, 1367, 1425, 1402,
#          '2015-05', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'May', 10019, 1527, 1640,
#          1578, '2016-05', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2014, 'November', 10153, 1438, 1577,
#          1507, '2014-11', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'November', 7991, 1470, 1556,
#          1512, '2015-11', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2014, 'October', 2195, 1591, 1749,
#          1670, '2014-10', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'October', 3326, 1452, 1531,
#          1491, '2015-10', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'October', 4523, 1401, 1491,
#          1445, '2016-10', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2014, 'September', 2779, 1645, 1843,
#          1744, '2014-09', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2015, 'September', 3535, 1651, 1733,
#          1691, '2015-09', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'September', 1970, 1630, 1751,
#          1697, '2016-09', 'Gondiya', 'Maharashtra'],
#         ['Aamgaon', 'PADDY-UNHUSKED', 2016, 'November', 6382, 1388, 1451,
#          1419, '2016-11', 'Gondiya', 'Maharashtra']], dtype=object),
#  'Aarni': array([['Aarni', 'WHEAT(HUSKED)', 2015, 'April', 327, 1050, 1300, 1175,
#          '2015-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SORGUM(JAWAR)', 2015, 'April', 3017, 863, 1150, 1006,
#          '2015-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'April', 4690, 3700, 4050, 3875,
#          '2015-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2016, 'April', 1009, 5133, 5530, 5323,
#          '2016-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'April', 16510, 5500, 6150,
#          5825, '2015-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'April', 1990, 8500, 8954,
#          8720, '2016-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2016, 'April', 265, 4551, 5376,
#          4800, '2016-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'April', 630, 3000, 3400, 3200,
#          '2015-04', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2015, 'August', 160, 1410, 1507, 1445,
#          '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SORGUM(JAWAR)', 2015, 'August', 175, 1245, 1338, 1275,
#          '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'August', 50, 3800, 4150, 3980, '2015-08',
#          'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GREEN GRAM', 2015, 'August', 10, 6850, 7050, 6900,
#          '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'August', 275, 8333, 8930,
#          8623, '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'August', 410, 4800, 5350,
#          5150, '2016-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2015, 'August', 530, 5742,
#          5932, 5825, '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2016, 'August', 100, 4800,
#          5375, 5125, '2016-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'August', 350, 2963, 3237, 3081,
#          '2015-08', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'December', 4361, 7629, 9354,
#          8579, '2015-12', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2014, 'December', 2865, 2761, 3146, 2971,
#          '2014-12', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'December', 2030, 3220, 3612, 3481,
#          '2015-12', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2016, 'February', 3685, 3800, 4276, 4020,
#          '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'February', 28650, 5267, 5763,
#          5515, '2015-02', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'February', 8657, 7549, 8287,
#          8034, '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'February', 1780, 3000, 3300, 3150,
#          '2015-02', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'February', 1150, 3067, 3674, 3400,
#          '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'January', 175, 2000, 2200, 2100,
#          '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'January', 23286, 4723, 5327,
#          5040, '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'January', 12666, 8050, 9311,
#          8778, '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'January', 775, 2800, 3153, 2976,
#          '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'January', 2315, 3075, 3698, 3400,
#          '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'July', 60, 4000, 4490, 4245, '2015-07',
#          'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'July', 1750, 7980, 8516,
#          8280, '2016-07', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2016, 'July', 420, 5625, 6159,
#          5850, '2016-07', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'July', 40, 3000, 3260, 3130,
#          '2015-07', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'July', 605, 3200, 3664, 3450,
#          '2016-07', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2015, 'June', 150, 1100, 1400, 1250,
#          '2015-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SORGUM(JAWAR)', 2015, 'June', 182, 900, 1100, 1000,
#          '2015-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2016, 'June', 790, 5938, 6560, 6200, '2016-06',
#          'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'June', 774, 6500, 7000, 6750,
#          '2015-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'June', 3860, 8300, 8817,
#          8511, '2016-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2015, 'June', 3610, 5000, 5400,
#          5200, '2015-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2016, 'June', 3974, 5160, 5923,
#          5531, '2016-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'June', 575, 3500, 3800, 3650,
#          '2015-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'June', 1180, 3233, 3755, 3467,
#          '2016-06', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2015, 'March', 390, 975, 1275, 1125,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'March', 6695, 2942, 3317, 3129,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2016, 'March', 5205, 3838, 4241, 4038,
#          '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'March', 19792, 5488, 5908,
#          5698, '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'March', 4590, 7438, 8212,
#          7931, '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'March', 2535, 3000, 3300, 3150,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2016, 'May', 40, 1400, 1700, 1600,
#          '2016-05', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2015, 'May', 660, 3840, 4351, 4100, '2015-05',
#          'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2016, 'May', 1135, 5402, 5607, 5459, '2016-05',
#          'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'May', 2300, 8183, 8790, 8517,
#          '2016-05', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2016, 'May', 8566, 4573, 5512,
#          5151, '2016-05', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'May', 750, 3550, 3850, 3550,
#          '2016-05', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2014, 'November', 5950, 2900, 3312, 3126,
#          '2014-11', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'November', 7592, 3227, 3705, 3518,
#          '2015-11', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2014, 'October', 390, 1273, 1502, 1386,
#          '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2014, 'October', 365, 2225, 2575, 2400,
#          '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2014, 'October', 50, 4300, 4800,
#          4550, '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'October', 16, 10775, 10775,
#          10775, '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'October', 1353, 6104, 6609,
#          6371, '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'BLACK GRAM', 2016, 'October', 100, 5167, 6850, 6333,
#          '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2014, 'October', 750, 3550,
#          3832, 3717, '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2014, 'October', 3080, 2888, 3237, 3051,
#          '2014-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'October', 20932, 3284, 3703, 3522,
#          '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'October', 9200, 2195, 2860, 2636,
#          '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2014, 'September', 539, 1238, 1545,
#          1388, '2014-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'WHEAT(HUSKED)', 2015, 'September', 236, 1366, 1510,
#          1471, '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SORGUM(JAWAR)', 2015, 'September', 165, 1244, 1313,
#          1273, '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GRAM', 2014, 'September', 410, 2225, 2575, 2400,
#          '2014-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GREEN GRAM', 2015, 'September', 65, 6880, 7470, 7088,
#          '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GREEN GRAM', 2016, 'September', 55, 4867, 5550, 5250,
#          '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2014, 'September', 70, 4020, 4910,
#          4650, '2014-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2015, 'September', 223, 8780, 9590,
#          9230, '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'PIGEON PEA (TUR)', 2016, 'September', 2145, 6313, 6859,
#          6650, '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'BLACK GRAM', 2015, 'September', 25, 8165, 8536, 8315,
#          '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'BLACK GRAM', 2016, 'September', 67, 6050, 6567, 6317,
#          '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'GROUND NUT PODS (DRY)', 2014, 'September', 1350, 3694,
#          3964, 3830, '2014-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2014, 'September', 165, 3000, 3450, 3270,
#          '2014-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2015, 'September', 1159, 3015, 3287, 3155,
#          '2015-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'September', 1485, 2933, 3267, 3115,
#          '2016-09', 'Yewatmal', 'Maharashtra'],
#         ['Aarni', 'SOYBEAN', 2016, 'November', 13960, 2463, 2851, 2666,
#          '2016-11', 'Yewatmal', 'Maharashtra']], dtype=object),
#  'Achalpur': array([['Achalpur', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Achalpur', 'GRAM', 2015, ..., '2015-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Achalpur', 'PIGEON PEA (TUR)', 2015, ..., '2015-04',
#          'Amaravathi', 'Maharashtra'],
#         ...,
#         ['Achalpur', 'BLACK GRAM', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Achalpur', 'SOYBEAN', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Achalpur', 'SESAMUM', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra']], dtype=object),
#  'Aheri': array([['Aheri', 'COTTON', 2016, ..., '2016-04', 'Gadchiroli',
#          'Maharashtra'],
#         ['Aheri', 'PADDY-UNHUSKED', 2015, ..., '2015-04', 'Gadchiroli',
#          'Maharashtra'],
#         ['Aheri', 'PADDY-UNHUSKED', 2016, ..., '2016-04', 'Gadchiroli',
#          'Maharashtra'],
#         ...,
#         ['Aheri', 'GRAM', 2016, ..., '2016-11', 'Gadchiroli',
#          'Maharashtra'],
#         ['Aheri', 'SOYBEAN', 2016, ..., '2016-11', 'Gadchiroli',
#          'Maharashtra'],
#         ['Aheri', 'SESAMUM', 2016, ..., '2016-11', 'Gadchiroli',
#          'Maharashtra']], dtype=object),
#  'Ahmednagar': array([['Ahmednagar', 'BAJRI', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'BAJRI', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'WHEAT(HUSKED)', 2015, ..., '2015-04',
#          'Ahmadnagar', 'Maharashtra'],
#         ...,
#         ['Ahmednagar', 'TOMATO', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'BRINJAL', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Ahmednagar', 'GREEN CHILLI', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'Ahmedpur': array([['Ahmedpur', 'BAJRI', 2016, ..., '2016-04', 'Latur',
#          'Maharashtra'],
#         ['Ahmedpur', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Latur',
#          'Maharashtra'],
#         ['Ahmedpur', 'SORGUM(JAWAR)', 2016, ..., '2016-04', 'Latur',
#          'Maharashtra'],
#         ...,
#         ['Ahmedpur', 'SOYBEAN', 2016, ..., '2016-11', 'Latur',
#          'Maharashtra'],
#         ['Ahmedpur', 'SUNFLOWER', 2016, ..., '2016-11', 'Latur',
#          'Maharashtra'],
#         ['Ahmedpur', 'SESAMUM', 2016, ..., '2016-11', 'Latur',
#          'Maharashtra']], dtype=object),
#  'Akhadabalapur': array([['Akhadabalapur', 'WHEAT(HUSKED)', 2015, ..., '2015-04',
#          'Hingoli', 'Maharashtra'],
#         ['Akhadabalapur', 'WHEAT(HUSKED)', 2016, ..., '2016-04',
#          'Hingoli', 'Maharashtra'],
#         ['Akhadabalapur', 'SORGUM(JAWAR)', 2015, ..., '2015-04',
#          'Hingoli', 'Maharashtra'],
#         ...,
#         ['Akhadabalapur', 'SORGUM(JAWAR)', 2016, ..., '2016-11',
#          'Hingoli', 'Maharashtra'],
#         ['Akhadabalapur', 'GRAM', 2016, ..., '2016-11', 'Hingoli',
#          'Maharashtra'],
#         ['Akhadabalapur', 'SOYBEAN', 2016, ..., '2016-11', 'Hingoli',
#          'Maharashtra']], dtype=object),
#  'Akkalkuwa': array([['Akkalkuwa', 'WHEAT(HUSKED)', 2015, 'April', 400, 1200, 1500,
#          1400, '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'OTHER CEREALS', 2015, 'April', 50, 6000, 7400,
#          7000, '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2015, 'April', 100, 1200, 1750,
#          1500, '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GRAM', 2015, 'April', 120, 2800, 3450, 3250,
#          '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GREEN GRAM', 2015, 'April', 70, 6000, 7200, 6750,
#          '2015-04', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2015, 'December', 286, 1350, 1410,
#          1377, '2015-12', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2015, 'December', 360, 1321, 1365, 1341,
#          '2015-12', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'WHEAT(HUSKED)', 2016, 'February', 645, 1450, 1600,
#          1500, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2016, 'February', 1312, 1300, 1400,
#          1360, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2016, 'February', 564, 1390, 1410, 1400,
#          '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GREEN GRAM', 2016, 'February', 320, 6200, 6500,
#          6400, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'PIGEON PEA (TUR)', 2016, 'February', 220, 6700,
#          7500, 7000, '2016-02', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'WHEAT(HUSKED)', 2016, 'March', 810, 1450, 1550,
#          1500, '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2016, 'March', 100, 1300, 1350,
#          1330, '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2016, 'March', 300, 1370, 1400, 1390,
#          '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GRAM', 2016, 'March', 25, 4100, 4200, 4150,
#          '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'PIGEON PEA (TUR)', 2016, 'March', 20, 6700, 7000,
#          6850, '2016-03', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'WHEAT(HUSKED)', 2015, 'May', 350, 1200, 1400, 1350,
#          '2015-05', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GRAM', 2015, 'May', 75, 3500, 4000, 3700,
#          '2015-05', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'GREEN GRAM', 2015, 'May', 130, 7300, 7500, 7400,
#          '2015-05', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'WHEAT(HUSKED)', 2015, 'November', 230, 1300, 1450,
#          1400, '2015-11', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2015, 'November', 1165, 1150, 1350,
#          1275, '2015-11', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2015, 'November', 1655, 1263, 1405, 1350,
#          '2015-11', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'WHEAT(HUSKED)', 2015, 'October', 200, 1200, 1450,
#          1400, '2015-10', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2015, 'October', 278, 1200, 1400,
#          1350, '2015-10', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2015, 'October', 250, 1100, 1400, 1300,
#          '2015-10', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'SORGUM(JAWAR)', 2016, 'November', 115, 1340, 1350,
#          1345, '2016-11', 'Nandurbar', 'Maharashtra'],
#         ['Akkalkuwa', 'MAIZE', 2016, 'November', 480, 1327, 1358, 1343,
#          '2016-11', 'Nandurbar', 'Maharashtra']], dtype=object),
#  'Akkolkot': array([['Akkolkot', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Solapur',
#          'Maharashtra'],
#         ['Akkolkot', 'SORGUM(JAWAR)', 2016, ..., '2016-04', 'Solapur',
#          'Maharashtra'],
#         ['Akkolkot', 'WHEAT(UNHUSKED)', 2015, ..., '2015-04', 'Solapur',
#          'Maharashtra'],
#         ...,
#         ['Akkolkot', 'GREEN GRAM', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra'],
#         ['Akkolkot', 'PIGEON PEA (TUR)', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra'],
#         ['Akkolkot', 'BLACK GRAM', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra']], dtype=object),
#  'Akluj': array([['Akluj', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Solapur',
#          'Maharashtra'],
#         ['Akluj', 'SORGUM(JAWAR)', 2015, ..., '2015-04', 'Solapur',
#          'Maharashtra'],
#         ['Akluj', 'MAIZE', 2015, ..., '2015-04', 'Solapur', 'Maharashtra'],
#         ...,
#         ['Akluj', 'BRINJAL', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra'],
#         ['Akluj', 'GOATS', 2016, ..., '2016-11', 'Solapur', 'Maharashtra'],
#         ['Akluj', 'CHILLIES(RED)', 2016, ..., '2016-11', 'Solapur',
#          'Maharashtra']], dtype=object),
#  'Akola': array([['Akola', 'BAJRI', 2015, ..., '2015-04', 'Akola', 'Maharashtra'],
#         ['Akola', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Akola',
#          'Maharashtra'],
#         ['Akola', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Akola',
#          'Maharashtra'],
#         ...,
#         ['Akola', 'SAFFLOWER', 2016, ..., '2016-11', 'Akola',
#          'Maharashtra'],
#         ['Akola', 'SOYBEAN', 2016, ..., '2016-11', 'Akola', 'Maharashtra'],
#         ['Akola', 'SESAMUM', 2016, ..., '2016-11', 'Akola', 'Maharashtra']],
#        dtype=object),
#  'Akole': array([['Akole', 'BAJRI', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Akole', 'BAJRI', 2016, ..., '2016-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Akole', 'PADDY-UNHUSKED', 2015, ..., '2015-04', 'Ahmadnagar',
#          'Maharashtra'],
#         ...,
#         ['Akole', 'SOYBEAN', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Akole', 'ONION', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra'],
#         ['Akole', 'TOMATO', 2016, ..., '2016-11', 'Ahmadnagar',
#          'Maharashtra']], dtype=object),
#  'Akot': array([['Akot', 'COTTON', 2015, ..., '2015-04', 'Akola', 'Maharashtra'],
#         ['Akot', 'COTTON', 2016, ..., '2016-04', 'Akola', 'Maharashtra'],
#         ['Akot', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Akola',
#          'Maharashtra'],
#         ...,
#         ['Akot', 'BLACK GRAM', 2016, ..., '2016-11', 'Akola',
#          'Maharashtra'],
#         ['Akot', 'SOYBEAN', 2016, ..., '2016-11', 'Akola', 'Maharashtra'],
#         ['Akot', 'SESAMUM', 2016, ..., '2016-11', 'Akola', 'Maharashtra']],
#        dtype=object),
#  'Alibag': array([['Alibag', 'PADDY-UNHUSKED', 2016, 'April', 910, 1450, 1500, 1475,
#          '2016-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'April', 870, 1500, 1700,
#          1600, '2015-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'April', 780, 3500, 4500,
#          4000, '2016-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'COCONUT', 2016, 'April', 780, 2500, 3058, 2769,
#          '2016-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'April', 780, 1500, 2500, 2000,
#          '2016-04', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'August', 715, 1478, 1678,
#          1578, '2015-08', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'August', 722, 1499, 1548,
#          1524, '2016-08', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'August', 890, 2203, 2403,
#          2303, '2015-08', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'August', 710, 3504, 4504,
#          4004, '2016-08', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'December', 836, 1500, 1700,
#          1600, '2015-12', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2014, 'December', 870, 1500, 1700,
#          1600, '2014-12', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'December', 842, 3370, 4000,
#          3657, '2015-12', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'February', 725, 1450, 1550,
#          1502, '2016-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'February', 600, 1500, 1700,
#          1600, '2015-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'February', 720, 3500, 4188,
#          3813, '2016-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'COCONUT', 2016, 'February', 5100, 1603, 2105, 1854,
#          '2016-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'February', 7080, 1240, 1901, 1460,
#          '2016-02', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'January', 750, 1454, 1562,
#          1508, '2016-01', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'January', 870, 1500, 1700,
#          1600, '2015-01', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'January', 750, 3500, 4000,
#          3750, '2016-01', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'COCONUT', 2016, 'January', 3000, 10, 20, 15,
#          '2016-01', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'January', 3000, 1, 3, 2, '2016-01',
#          'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'July', 780, 1415, 1623, 1519,
#          '2015-07', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'July', 720, 1500, 1550, 1525,
#          '2016-07', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'July', 900, 2113, 2333, 2223,
#          '2015-07', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'July', 720, 3500, 4500, 4000,
#          '2016-07', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'June', 370, 1467, 1675, 1571,
#          '2015-06', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'June', 695, 1500, 1550, 1525,
#          '2016-06', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'June', 799, 3077, 3500, 3281,
#          '2015-06', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'June', 720, 3500, 4500, 4000,
#          '2016-06', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'March', 760, 1450, 1538, 1495,
#          '2016-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'March', 660, 1500, 1700,
#          1600, '2015-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'March', 810, 3500, 4500,
#          3944, '2016-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'COCONUT', 2016, 'March', 9690, 2385, 2973, 2679,
#          '2016-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'March', 9660, 1428, 2264, 1836,
#          '2016-03', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'May', 750, 1440, 1542, 1517,
#          '2016-05', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'May', 808, 2060, 2492, 2276,
#          '2015-05', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'May', 756, 3339, 4265, 3802,
#          '2016-05', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'COCONUT', 2016, 'May', 630, 2500, 3500, 3000,
#          '2016-05', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'BETELNUTS', 2016, 'May', 630, 1500, 2500, 2000,
#          '2016-05', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'November', 784, 1500, 1700,
#          1679, '2015-11', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2014, 'November', 900, 1500, 1700,
#          1600, '2014-11', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'November', 777, 3000, 4000,
#          3500, '2015-11', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'October', 757, 1580, 1792,
#          1686, '2015-10', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'October', 750, 1489, 1526,
#          1508, '2016-10', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2014, 'October', 900, 1500, 1700,
#          1600, '2014-10', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'October', 880, 2228, 2624,
#          2429, '2015-10', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'October', 750, 3500, 4500,
#          4000, '2016-10', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2015, 'September', 665, 1500, 1700,
#          1600, '2015-09', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'September', 690, 1543, 1634,
#          1588, '2016-09', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2014, 'September', 870, 1500, 1700,
#          1603, '2014-09', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2015, 'September', 750, 3172, 3372,
#          3272, '2015-09', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'September', 690, 3500, 4500,
#          4000, '2016-09', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'PADDY-UNHUSKED', 2016, 'November', 690, 1480, 1500,
#          1490, '2016-11', 'Raigad', 'Maharashtra'],
#         ['Alibag', 'RICE(PADDY-HUS)', 2016, 'November', 690, 3324, 4239,
#          3782, '2016-11', 'Raigad', 'Maharashtra']], dtype=object),
#  'Amalner': array([['Amalner', 'BAJRI', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ['Amalner', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ['Amalner', 'SORGUM(JAWAR)', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ...,
#         ['Amalner', 'SOYBEAN', 2016, ..., '2016-11', 'Jalgaon',
#          'Maharashtra'],
#         ['Amalner', 'SESAMUM', 2016, ..., '2016-11', 'Jalgaon',
#          'Maharashtra'],
#         ['Amalner', 'ONION', 2016, ..., '2016-11', 'Jalgaon',
#          'Maharashtra']], dtype=object),
#  'Amarawati': array([['Amarawati', 'COTTON', 2016, ..., '2016-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Amarawati', 'BAJRI', 2015, ..., '2015-04', 'Amaravathi',
#          'Maharashtra'],
#         ['Amarawati', 'BAJRI', 2016, ..., '2016-04', 'Amaravathi',
#          'Maharashtra'],
#         ...,
#         ['Amarawati', 'SOYBEAN', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Amarawati', 'SUNFLOWER', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Amarawati', 'SESAMUM', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra']], dtype=object),
#  'Amarawati-Fruit And Vegetables': array([['Amarawati-Fruit And Vegetables', 'POMEGRANATE', 2016, ...,
#          '2016-04', 'Amaravathi', 'Maharashtra'],
#         ['Amarawati-Fruit And Vegetables', 'GRAPES', 2016, ..., '2016-04',
#          'Amaravathi', 'Maharashtra'],
#         ['Amarawati-Fruit And Vegetables', 'PAPAI', 2016, ..., '2016-04',
#          'Amaravathi', 'Maharashtra'],
#         ...,
#         ['Amarawati-Fruit And Vegetables', 'GREEN-PEAS', 2016, ...,
#          '2016-11', 'Amaravathi', 'Maharashtra'],
#         ['Amarawati-Fruit And Vegetables', 'BRINJAL', 2016, ...,
#          '2016-11', 'Amaravathi', 'Maharashtra'],
#         ['Amarawati-Fruit And Vegetables', 'GREEN CHILLI', 2016, ...,
#          '2016-11', 'Amaravathi', 'Maharashtra']], dtype=object),
#  'Ambad(Vadi Godri)': array([['Ambad(Vadi Godri)', 'BAJRI', 2016, ..., '2016-04', 'Jalna',
#          'Maharashtra'],
#         ['Ambad(Vadi Godri)', 'WHEAT(HUSKED)', 2016, ..., '2016-04',
#          'Jalna', 'Maharashtra'],
#         ['Ambad(Vadi Godri)', 'SORGUM(JAWAR)', 2016, ..., '2016-04',
#          'Jalna', 'Maharashtra'],
#         ...,
#         ['Ambad(Vadi Godri)', 'SORGUM(JAWAR)', 2016, ..., '2016-11',
#          'Jalna', 'Maharashtra'],
#         ['Ambad(Vadi Godri)', 'MAIZE', 2016, ..., '2016-11', 'Jalna',
#          'Maharashtra'],
#         ['Ambad(Vadi Godri)', 'SOYBEAN', 2016, ..., '2016-11', 'Jalna',
#          'Maharashtra']], dtype=object),
#  'Ambejogai': array([['Ambejogai', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Beed',
#          'Maharashtra'],
#         ['Ambejogai', 'SORGUM(JAWAR)', 2015, ..., '2015-04', 'Beed',
#          'Maharashtra'],
#         ['Ambejogai', 'SORGUM(JAWAR)', 2016, ..., '2016-04', 'Beed',
#          'Maharashtra'],
#         ...,
#         ['Ambejogai', 'PIGEON PEA (TUR)', 2016, ..., '2016-11', 'Beed',
#          'Maharashtra'],
#         ['Ambejogai', 'BLACK GRAM', 2016, ..., '2016-11', 'Beed',
#          'Maharashtra'],
#         ['Ambejogai', 'SOYBEAN', 2016, ..., '2016-11', 'Beed',
#          'Maharashtra']], dtype=object),
#  'Anajngaon Surji': array([['Anajngaon Surji', 'WHEAT(HUSKED)', 2015, ..., '2015-04',
#          'Amaravathi', 'Maharashtra'],
#         ['Anajngaon Surji', 'WHEAT(HUSKED)', 2016, ..., '2016-04',
#          'Amaravathi', 'Maharashtra'],
#         ['Anajngaon Surji', 'SORGUM(JAWAR)', 2015, ..., '2015-04',
#          'Amaravathi', 'Maharashtra'],
#         ...,
#         ['Anajngaon Surji', 'SOYBEAN', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Anajngaon Surji', 'BANANA', 2016, ..., '2016-11', 'Amaravathi',
#          'Maharashtra'],
#         ['Anajngaon Surji', 'CHILLIES(RED)', 2016, ..., '2016-11',
#          'Amaravathi', 'Maharashtra']], dtype=object),
#  'Arjuni Morgaon': array([['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'April', 2004, 1596,
#          1670, 1633, '2015-04', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'April', 4973, 1781,
#          1815, 1814, '2016-04', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'August', 1077, 1551,
#          1608, 1600, '2015-08', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'August', 4320, 1964,
#          2002, 2002, '2016-08', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2014, 'December', 5343, 1588,
#          1654, 1621, '2014-12', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'December', 12616,
#          1662, 1704, 1701, '2015-12', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'February', 2233, 1558,
#          1593, 1576, '2015-02', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'February', 10322,
#          1688, 1723, 1723, '2016-02', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'January', 3551, 1620,
#          1676, 1648, '2015-01', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'January', 4828, 1597,
#          1633, 1633, '2016-01', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'July', 4216, 1429,
#          1459, 1459, '2015-07', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'July', 8825, 2061,
#          2093, 2093, '2016-07', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'June', 13908, 1431,
#          1454, 1445, '2015-06', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'June', 8221, 1842,
#          1875, 1875, '2016-06', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'March', 2667, 1512,
#          1567, 1539, '2015-03', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'March', 8450, 1714,
#          1739, 1739, '2016-03', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'May', 15486, 1492,
#          1537, 1515, '2015-05', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'May', 8445, 1782,
#          1804, 1804, '2016-05', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2014, 'November', 6293, 1465,
#          1524, 1494, '2014-11', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'November', 5175, 1530,
#          1561, 1560, '2015-11', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2014, 'October', 2437, 1851,
#          1929, 1889, '2014-10', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'October', 167, 1750,
#          1825, 1800, '2015-10', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'October', 7039, 1930,
#          1958, 1958, '2016-10', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2014, 'September', 3394,
#          1911, 2005, 1959, '2014-09', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2015, 'September', 989, 2045,
#          2125, 2105, '2015-09', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'September', 4525,
#          2024, 2063, 2063, '2016-09', 'Gondiya', 'Maharashtra'],
#         ['Arjuni Morgaon', 'PADDY-UNHUSKED', 2016, 'November', 11846,
#          1563, 1580, 1580, '2016-11', 'Gondiya', 'Maharashtra']],
#        dtype=object),
#  'Armori': array([['Armori', 'PADDY-UNHUSKED', 2015, 'April', 1736, 1493, 1581,
#          1543, '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'April', 2989, 1709, 1818,
#          1784, '2016-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2015, 'April', 151, 3630,
#          4114, 3950, '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'CHILLIES(RED)', 2015, 'April', 9, 9167, 12333, 11258,
#          '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'CHILLIES(RED)', 2016, 'April', 15, 9667, 15467, 14192,
#          '2016-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'August', 2553, 1576, 1684,
#          1651, '2015-08', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'August', 1483, 1978, 2053,
#          2032, '2016-08', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2014, 'December', 11478, 1474, 1576,
#          1535, '2014-12', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'December', 25418, 1532, 1720,
#          1595, '2015-12', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'February', 6631, 1495, 1546,
#          1520, '2015-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'February', 9364, 1550, 1621,
#          1594, '2016-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2015, 'February', 1575, 3275,
#          4422, 3805, '2015-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2016, 'February', 2666, 4038,
#          5921, 5241, '2016-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'January', 6900, 1525, 1608,
#          1580, '2015-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'January', 19269, 1516, 1606,
#          1569, '2016-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2015, 'January', 60, 2636,
#          3279, 2856, '2015-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2016, 'January', 754, 4114,
#          5810, 5170, '2016-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'July', 4608, 1505, 1627, 1587,
#          '2015-07', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'July', 3275, 1823, 1950, 1916,
#          '2016-07', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'June', 4909, 1425, 1491, 1467,
#          '2015-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'June', 4642, 1725, 1846, 1817,
#          '2016-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'CHILLIES(RED)', 2015, 'June', 2, 11000, 14500, 14000,
#          '2015-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'March', 3896, 1498, 1543,
#          1524, '2015-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'March', 4544, 1625, 1686,
#          1657, '2016-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2015, 'March', 1586, 3274,
#          4504, 3984, '2015-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'GROUND NUT PODS (DRY)', 2016, 'March', 222, 3761,
#          4911, 4363, '2016-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'May', 2931, 1504, 1556, 1532,
#          '2015-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'May', 3646, 1646, 1783, 1742,
#          '2016-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'CHILLIES(RED)', 2016, 'May', 14, 15650, 18750, 17054,
#          '2016-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2014, 'November', 4630, 1675, 1774,
#          1724, '2014-11', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'November', 2383, 1502, 1646,
#          1602, '2015-11', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2014, 'October', 642, 2552, 2619,
#          2596, '2014-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'October', 1849, 1675, 1811,
#          1763, '2015-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'October', 2835, 1832, 1891,
#          1861, '2016-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2014, 'September', 2432, 2026, 2109,
#          2073, '2014-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2015, 'September', 3195, 1688, 1844,
#          1810, '2015-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'September', 2547, 1893, 1981,
#          1953, '2016-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori', 'PADDY-UNHUSKED', 2016, 'November', 8192, 1613, 1707,
#          1662, '2016-11', 'Gadchiroli', 'Maharashtra']], dtype=object),
#  'Armori-Desaiganj': array([['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'April', 30070, 1445,
#          1562, 1517, '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'April', 15488, 1630,
#          1749, 1733, '2016-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'April', 24, 7000,
#          12000, 10419, '2015-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'April', 128, 12250,
#          17600, 16875, '2016-04', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'August', 27551,
#          1544, 1703, 1668, '2015-08', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'August', 17896,
#          1733, 1902, 1854, '2016-08', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2014, 'December', 69619,
#          1450, 1624, 1550, '2014-12', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'December', 83247,
#          1512, 1668, 1641, '2015-12', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'February', 41469,
#          1472, 1601, 1548, '2015-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'February', 30072,
#          1548, 1667, 1651, '2016-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'February', 4, 13500,
#          13800, 13713, '2015-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'February', 24, 14433,
#          14833, 14667, '2016-02', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'January', 66101,
#          1470, 1648, 1579, '2015-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'January', 41138,
#          1511, 1639, 1620, '2016-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'January', 9, 14000,
#          14000, 14000, '2015-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'January', 6, 11250,
#          15250, 14474, '2016-01', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'July', 39609, 1500,
#          1669, 1634, '2015-07', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'July', 14303, 1740,
#          1901, 1876, '2016-07', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'June', 59931, 1440,
#          1592, 1536, '2015-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'June', 31517, 1745,
#          1930, 1907, '2016-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'June', 17, 11500,
#          15600, 13415, '2015-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'June', 3, 17000,
#          18500, 18300, '2016-06', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'March', 39897, 1443,
#          1552, 1508, '2015-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'March', 18210, 1559,
#          1664, 1651, '2016-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'March', 165, 7000,
#          13200, 11824, '2015-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'March', 207, 11500,
#          16620, 15900, '2016-03', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'May', 52354, 1444,
#          1672, 1521, '2015-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'May', 35957, 1695,
#          1850, 1819, '2016-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2015, 'May', 33, 10500,
#          14100, 13294, '2015-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2016, 'May', 94, 14075,
#          19025, 18375, '2016-05', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2014, 'November', 47448,
#          1485, 1745, 1629, '2014-11', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'November', 51355,
#          1482, 1679, 1617, '2015-11', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2014, 'November', 6, 12700,
#          12700, 12700, '2014-11', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2014, 'October', 9913,
#          1674, 1940, 1838, '2014-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'October', 29954,
#          1489, 1705, 1664, '2015-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'October', 17282,
#          1658, 1844, 1810, '2016-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'CHILLIES(RED)', 2014, 'October', 3, 11700,
#          12636, 12133, '2014-10', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2014, 'September', 33424,
#          1700, 1953, 1871, '2014-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2015, 'September', 38625,
#          1596, 1796, 1765, '2015-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'September', 21028,
#          1706, 2052, 1843, '2016-09', 'Gadchiroli', 'Maharashtra'],
#         ['Armori-Desaiganj', 'PADDY-UNHUSKED', 2016, 'November', 50811,
#          1540, 1691, 1652, '2016-11', 'Gadchiroli', 'Maharashtra']],
#        dtype=object),
#  'Arvi': array([['Arvi', 'COTTON', 2015, 'April', 46424, 4000, 4538, 4280,
#          '2015-04', 'Wardha', 'Maharashtra'],
#         ['Arvi', 'COTTON', 2016, 'April', 102596, 4844, 4909, 4881,
#          '2016-04', 'Wardha', 'Maharashtra'],
# ...
#          2217, 2141, '2015-12', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'MAIZE', 2015, 'December', 148, 1356, 1436,
#          1393, '2015-12', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SOYBEAN', 2015, 'December', 178, 3452, 3572,
#          3518, '2015-12', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SUNFLOWER', 2015, 'December', 15, 2890,
#          3000, 2900, '2015-12', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'GRAM', 2016, 'February', 40, 4033, 4233,
#          4117, '2016-02', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SOYBEAN', 2016, 'February', 37, 3433, 3567,
#          3473, '2016-02', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SORGUM(JAWAR)', 2016, 'January', 30, 2000,
#          2125, 2050, '2016-01', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'MAIZE', 2016, 'January', 28, 1320, 1450,
#          1350, '2016-01', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SOYBEAN', 2016, 'January', 23, 3400, 3550,
#          3500, '2016-01', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'GRAM', 2016, 'March', 20, 4000, 4200, 4100,
#          '2016-03', 'Osmanabad', 'Maharashtra'],
#         ['Washi(Osmanabad)', 'SOYBEAN', 2016, 'March', 20, 3400, 3600,
#          3500, '2016-03', 'Osmanabad', 'Maharashtra']], dtype=object),
#  'Washim': array([['Washim', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Wasim',
#          'Maharashtra'],
#         ['Washim', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Wasim',
#          'Maharashtra'],
#         ['Washim', 'SORGUM(JAWAR)', 2015, ..., '2015-04', 'Wasim',
#          'Maharashtra'],
#         ...,
#         ['Washim', 'BLACK GRAM', 2016, ..., '2016-11', 'Wasim',
#          'Maharashtra'],
#         ['Washim', 'SOYBEAN', 2016, ..., '2016-11', 'Wasim',
#          'Maharashtra'],
#         ['Washim', 'TURMERIC', 2016, ..., '2016-11', 'Wasim',
#          'Maharashtra']], dtype=object),
#  'Washim-Ansing': array([['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'August', 24, 1483, 1600,
#          1538, '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'August', 9, 1385, 1433,
#          1403, '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'August', 106, 6089, 6189, 6128,
#          '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'August', 8, 4101, 4196,
#          4158, '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'August', 961, 6569,
#          6761, 6679, '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'August', 1730, 3469, 3656,
#          3578, '2016-08', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'July', 13, 1567, 1680,
#          1617, '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'July', 9, 1271, 1327,
#          1289, '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'July', 104, 7500, 7929, 7817,
#          '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'July', 123, 5033, 5270,
#          5167, '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'July', 1575, 8204,
#          8461, 8332, '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'July', 81, 9400, 9650,
#          9550, '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'July', 2415, 3523, 3774, 3652,
#          '2016-07', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'June', 14, 1490, 1528,
#          1503, '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'June', 39, 1276, 1343,
#          1304, '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'June', 153, 6003, 6506, 6307,
#          '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'June', 25, 5278, 5466,
#          5308, '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'June', 2490, 8803,
#          9132, 8966, '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'June', 3, 9883, 9883, 9883,
#          '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'June', 5590, 3665, 3872, 3775,
#          '2016-06', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'May', 39, 1640, 1707,
#          1690, '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'May', 24, 1233, 1333,
#          1283, '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'May', 360, 6289, 6433, 6348,
#          '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'May', 10, 5763, 5800, 5775,
#          '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'May', 1150, 8817,
#          9043, 8938, '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'May', 1, 10000, 10000,
#          10000, '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'May', 2400, 3673, 3872, 3729,
#          '2016-05', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'October', 23, 1675,
#          1720, 1705, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'October', 11, 1233,
#          1325, 1277, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'October', 26, 8675, 8950, 8800,
#          '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'October', 155, 4718, 4906,
#          4847, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'October', 1231, 6529,
#          6713, 6641, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'October', 585, 6792, 7297,
#          7149, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'October', 7450, 2696, 3033,
#          2885, '2016-10', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'September', 21, 1591,
#          1685, 1659, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SORGUM(JAWAR)', 2016, 'September', 24, 1260,
#          1362, 1337, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'September', 20, 7850, 8150, 8073,
#          '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'September', 131, 4863,
#          5081, 5015, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'September', 1142,
#          6774, 7056, 7006, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'September', 472, 6550,
#          6833, 6772, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'September', 720, 3225, 3416,
#          3357, '2016-09', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'WHEAT(HUSKED)', 2016, 'November', 18, 1567,
#          1760, 1692, '2016-11', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GRAM', 2016, 'November', 12, 7000, 7250, 7190,
#          '2016-11', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'GREEN GRAM', 2016, 'November', 18, 4833, 5150,
#          4942, '2016-11', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'PIGEON PEA (TUR)', 2016, 'November', 163, 5767,
#          6000, 5883, '2016-11', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'BLACK GRAM', 2016, 'November', 109, 6486, 6956,
#          6712, '2016-11', 'Wasim', 'Maharashtra'],
#         ['Washim-Ansing', 'SOYBEAN', 2016, 'November', 7950, 2600, 2905,
#          2763, '2016-11', 'Wasim', 'Maharashtra']], dtype=object),
#  'Yawal': array([['Yawal', 'COTTON', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ['Yawal', 'WHEAT(HUSKED)', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ['Yawal', 'SORGUM(JAWAR)', 2016, ..., '2016-04', 'Jalgaon',
#          'Maharashtra'],
#         ...,
#         ['Yawal', 'MAIZE', 2016, ..., '2016-11', 'Jalgaon', 'Maharashtra'],
#         ['Yawal', 'SOYBEAN', 2016, ..., '2016-11', 'Jalgaon',
#          'Maharashtra'],
#         ['Yawal', 'BANANA', 2016, ..., '2016-11', 'Jalgaon',
#          'Maharashtra']], dtype=object),
#  'Yeola': array([['Yeola', 'BAJRI', 2015, ..., '2015-04', 'Nasik', 'Maharashtra'],
#         ['Yeola', 'BAJRI', 2016, ..., '2016-04', 'Nasik', 'Maharashtra'],
#         ['Yeola', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Nasik',
#          'Maharashtra'],
#         ...,
#         ['Yeola', 'BLACK GRAM', 2016, ..., '2016-11', 'Nasik',
#          'Maharashtra'],
#         ['Yeola', 'SOYBEAN', 2016, ..., '2016-11', 'Nasik', 'Maharashtra'],
#         ['Yeola', 'ONION', 2016, ..., '2016-11', 'Nasik', 'Maharashtra']],
#        dtype=object),
#  'Yeotmal': array([['Yeotmal', 'COTTON', 2015, ..., '2015-04', 'Yewatmal',
#          'Maharashtra'],
#         ['Yeotmal', 'COTTON', 2016, ..., '2016-04', 'Yewatmal',
#          'Maharashtra'],
#         ['Yeotmal', 'WHEAT(HUSKED)', 2015, ..., '2015-04', 'Yewatmal',
#          'Maharashtra'],
#         ...,
#         ['Yeotmal', 'PIGEON PEA (TUR)', 2016, ..., '2016-11', 'Yewatmal',
#          'Maharashtra'],
#         ['Yeotmal', 'BLACK GRAM', 2016, ..., '2016-11', 'Yewatmal',
#          'Maharashtra'],
#         ['Yeotmal', 'SOYBEAN', 2016, ..., '2016-11', 'Yewatmal',
#          'Maharashtra']], dtype=object),
#  'Zarijamini': array([['Zarijamini', 'SOYBEAN', 2016, 'April', 88, 3481, 3489, 3483,
#          '2016-04', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2014, 'December', 19375, 3889, 4028,
#          4005, '2014-12', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'December', 40232, 4060, 4182,
#          4158, '2015-12', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'December', 12, 8210,
#          8400, 8225, '2015-12', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2014, 'December', 23, 2692, 3078, 2824,
#          '2014-12', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'February', 14449, 3802, 4048,
#          3978, '2015-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2016, 'February', 529, 4100, 4570, 4442,
#          '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2016, 'February', 318, 3584, 3878, 3786,
#          '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GREEN GRAM', 2016, 'February', 1, 6800, 6800,
#          6800, '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'February', 1196, 5150,
#          5468, 5367, '2015-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2016, 'February', 2839, 6740,
#          7272, 6897, '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'February', 30, 2858, 2886, 2876,
#          '2015-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2016, 'February', 48, 3350, 3390, 3377,
#          '2016-02', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'January', 15326, 3877, 4050, 4018,
#          '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2016, 'January', 310, 4405, 4513, 4446,
#          '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SORGUM(JAWAR)', 2016, 'January', 18, 1550, 1550,
#          1550, '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2016, 'January', 29, 3748, 3803, 3789,
#          '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GREEN GRAM', 2016, 'January', 1, 5700, 5700, 5700,
#          '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'January', 133, 4630,
#          4923, 4818, '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2016, 'January', 5067, 7890,
#          8228, 8114, '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'January', 8, 2938, 2938, 2938,
#          '2015-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2016, 'January', 69, 3221, 3286, 3257,
#          '2016-01', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GROUND NUT PODS (DRY)', 2015, 'July', 210, 4050,
#          4050, 4050, '2015-07', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GROUND NUT PODS (DRY)', 2016, 'June', 65, 4800,
#          4800, 4800, '2016-06', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'March', 2089, 3800, 3953, 3897,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2015, 'March', 34, 3074, 3171, 3129,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2016, 'March', 95, 2717, 4017, 3956,
#          '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'March', 230, 4913, 5550,
#          5358, '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2016, 'March', 40, 7300, 7400,
#          7344, '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'March', 6, 2825, 2850, 2843,
#          '2015-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2016, 'March', 51, 3400, 3400, 3400,
#          '2016-03', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'WHEAT(HUSKED)', 2015, 'May', 1, 1500, 1500, 1500,
#          '2015-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2015, 'May', 38, 3503, 3661, 3630,
#          '2015-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'May', 80, 6170, 6392,
#          6313, '2015-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GROUND NUT PODS (DRY)', 2015, 'May', 399, 4188,
#          4188, 4188, '2015-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GROUND NUT PODS (DRY)', 2016, 'May', 1561, 4775,
#          4864, 4818, '2016-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'May', 1, 3260, 3260, 3260,
#          '2015-05', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2014, 'November', 5153, 3880, 4001, 3945,
#          '2014-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'November', 51557, 3913, 4037,
#          4015, '2015-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SORGUM(JAWAR)', 2015, 'November', 10, 1550, 1550,
#          1550, '2015-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'November', 2, 6500,
#          6500, 6500, '2015-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2014, 'November', 506, 2802, 3103, 2968,
#          '2014-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'November', 210, 2824, 7826, 3041,
#          '2015-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2015, 'October', 3707, 3913, 4098, 4032,
#          '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SORGUM(JAWAR)', 2015, 'October', 231, 1166, 1174,
#          1172, '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'GRAM', 2015, 'October', 3, 4800, 4800, 4800,
#          '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2015, 'October', 2, 9055, 9055,
#          9055, '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'PIGEON PEA (TUR)', 2016, 'October', 5, 5115, 5115,
#          5115, '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2015, 'October', 2534, 3184, 3595, 3476,
#          '2015-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2016, 'October', 1033, 1826, 2621, 2425,
#          '2016-10', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'COTTON', 2016, 'November', 18892, 4651, 4845,
#          4793, '2016-11', 'Yewatmal', 'Maharashtra'],
#         ['Zarijamini', 'SOYBEAN', 2016, 'November', 1333, 2228, 2726,
#          2601, '2016-11', 'Yewatmal', 'Maharashtra']], dtype=object)}

# %%
data1.info()
nan=float('nan')
matrix1=data1.as_matrix()
matrix1=matrix1[matrix1[:,3]!=nan][:,3]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 5 columns):
# commodity     155 non-null object
# year          155 non-null int64
# Type          155 non-null object
# msprice       145 non-null float64
# msp_filter    155 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.1+ KB

# %%
data2=data2[(data2['max_price']-data2['min_price'])>0]
data2=data2[data2['min_price'] <=data2['modal_price']]
data2=data2[data2['max_price'] >=data2['modal_price']]

# %%
for x in commodity_dict.keys():    #preprocessing
    commodity_dict[x]=commodity_dict[x][commodity_dict[x][:,7]!=nan]
    commodity_dict[x]=commodity_dict[x][commodity_dict[x][:,6]!=nan]
    commodity_dict[x]=commodity_dict[x][commodity_dict[x][:,5]!=nan]
    commodity_dict[x]=commodity_dict[x][commodity_dict[x][:,4]!=nan]
    
    Q1_modal_price=np.percentile(commodity_dict[x][:,7], 25)   #https://stackoverflow.com/questions/43189590/how-do-i-eliminate-outliers-in-pricing-data
    Q3_modal_price=np.percentile(commodity_dict[x][:,7], 75)
    IQR_modal_price = Q3_modal_price-Q1_modal_price
    commodity_dict[x]=commodity_dict[x][commodity_dict[x][:,7] <(Q3_modal_price+1.5*IQR_modal_price)]
    commodity_dict[x]=commodity_dict[x][(Q1_modal_price-1.5*IQR_modal_price) < commodity_dict[x][:,7]]

# %%
for x in APMC_dict.keys():   #preprocessing
    APMC_dict[x]=APMC_dict[x][APMC_dict[x][:,7]!=nan]
    APMC_dict[x]=APMC_dict[x][APMC_dict[x][:,6]!=nan]
    APMC_dict[x]=APMC_dict[x][APMC_dict[x][:,5]!=nan]
    APMC_dict[x]=APMC_dict[x][APMC_dict[x][:,4]!=nan]
    
    Q1_modal_price=np.percentile(APMC_dict[x][:,7], 25)   #https://stackoverflow.com/questions/43189590/how-do-i-eliminate-outliers-in-pricing-data
    Q3_modal_price=np.percentile(APMC_dict[x][:,7], 75)
    IQR_modal_price = Q3_modal_price-Q1_modal_price
    APMC_dict[x]=APMC_dict[x][APMC_dict[x][:,7] <(Q3_modal_price+1.5*IQR_modal_price)]
    APMC_dict[x]=APMC_dict[x][(Q1_modal_price-1.5*IQR_modal_price) < APMC_dict[x][:,7]]

# %%
print(matrix2.shape)
matrix2=matrix2[matrix2[:,7]!=nan]
matrix2=matrix2[matrix2[:,6]!=nan]
matrix2=matrix2[matrix2[:,5]!=nan]
matrix2=matrix2[matrix2[:,4]!=nan]
#matrix2=matrix2[(matrix2[:,6]-matrix2[:,5])>0]
matrix2.shape
# Out:
# (62429, 11)
# (62429, 11)

# %%
Q1_modal_price=np.percentile(matrix2[:,7], 25)   #https://stackoverflow.com/questions/43189590/how-do-i-eliminate-outliers-in-pricing-data
Q3_modal_price=np.percentile(matrix2[:,7], 75)
IQR_modal_price = Q3_modal_price-Q1_modal_price
print(IQR_modal_price)
print(Q1_modal_price)
print(Q3_modal_price)
matrix2=matrix2[matrix2[:,7] <(Q3_modal_price+1.5*IQR_modal_price)]
matrix2=matrix2[(Q1_modal_price-1.5*IQR_modal_price) < matrix2[:,7]] 
print(matrix2.shape)
# Out:
# 2807.0
# 1450.0
# 4257.0
# (59896, 11)

# %%
Q1_max_price=np.percentile(matrix2[:,6], 25)   #https://stackoverflow.com/questions/43189590/how-do-i-eliminate-outliers-in-pricing-data
Q3_max_price=np.percentile(matrix2[:,6], 75)
IQR_max_price = Q3_max_price-Q1_max_price
print(IQR_max_price)
print(Q1_max_price)
print(Q3_max_price)
matrix2=matrix2[matrix2[:,6] <(Q3_max_price+1.5*IQR_max_price)]
matrix2=matrix2[(Q1_max_price-1.5*IQR_max_price) < matrix2[:,6]] 
print(matrix2.shape)
# Out:
# 2763.0
# 1573.0
# 4336.0
# (58826, 11)

# %%
Q1_min_price=np.percentile(matrix2[:,5], 25)   #https://stackoverflow.com/questions/43189590/how-do-i-eliminate-outliers-in-pricing-data
Q3_min_price=np.percentile(matrix2[:,5], 75)
IQR_min_price = Q3_min_price-Q1_min_price
print(IQR_min_price)
print(Q1_min_price)
print(Q3_min_price)
matrix2=matrix2[matrix2[:,5] <(Q3_min_price+1.5*IQR_min_price)]
matrix2=matrix2[(Q1_min_price-1.5*IQR_min_price) < matrix2[:,5]] 
print(matrix2.shape)
# Out:
# 2298.0
# 1208.0
# 3506.0
# (57098, 11)

# %%
data2['datetime'] = pd.to_datetime(data2['date'])
data2.index=data2['datetime']
#del data2['date']
data=data2.as_matrix()
data=pd.DataFrame()
data['jflg']=data2['arrivals_in_qtl']*data2['modal_price']

# %%
data2=data2.sort_values(by='date')
data2['jflg']=data2['arrivals_in_qtl']*data2['modal_price']
data=data2.resample('M').mean()
data
# Out:
#                                APMC              Commodity  Year      Month  \
# datetime
# 2014-09-01                 Buldhana                   GRAM  2014  September
# 2014-09-01              Mangalwedha        WHEAT(UNHUSKED)  2014  September
# 2014-09-01                    Ghoti                 TOMATO  2014  September
# 2014-09-01                    Ghoti                BRINJAL  2014  September
# 2014-09-01              Mangalwedha          SORGUM(JAWAR)  2014  September
# 2014-09-01                Lasalgaon                  BAJRI  2014  September
# 2014-09-01                Lasalgaon          WHEAT(HUSKED)  2014  September
# 2014-09-01                Lasalgaon                  MAIZE  2014  September
# 2014-09-01                    Ghoti                CABBAGE  2014  September
# 2014-09-01              Mangalwedha          WHEAT(HUSKED)  2014  September
# 2014-09-01              Mangalwedha                  BAJRI  2014  September
# 2014-09-01                Lasalgaon             GREEN GRAM  2014  September
# 2014-09-01                Lasalgaon  GROUND NUT PODS (DRY)  2014  September
# 2014-09-01                Lasalgaon                SOYBEAN  2014  September
# 2014-09-01                Lasalgaon            POMEGRANATE  2014  September
# 2014-09-01                Lasalgaon                  ONION  2014  September
# 2014-09-01                 Kurdwadi                  ONION  2014  September
# 2014-09-01                Lasalgaon                   GRAM  2014  September
# 2014-09-01                Lasalgaon                 TOMATO  2014  September
# 2014-09-01              Mangalwedha                  MAIZE  2014  September
# 2014-09-01                    Ghoti                 FLOWER  2014  September
# 2014-09-01              Mangalwedha            RIDGE GOURD  2014  September
# 2014-09-01              Mangalwedha           BITTER GOURD  2014  September
# 2014-09-01                 Chandvad                  ONION  2014  September
# 2014-09-01                   Devala                  BAJRI  2014  September
# 2014-09-01              Mangalwedha               CUCUMBER  2014  September
# 2014-09-01                   Devala          WHEAT(HUSKED)  2014  September
# 2014-09-01                   Devala          SORGUM(JAWAR)  2014  September
# 2014-09-01                    Ghoti               CUCUMBER  2014  September
# 2014-09-01                   Devala                   GRAM  2014  September
# ...                             ...                    ...   ...        ...
# 2016-11-01  Sangli-Phale Bhajipalam                    BOR  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                 CHIKOO  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam            POMEGRANATE  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam            WATER MELON  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                MOSAMBI  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                  PAPAI  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                  APPLE  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                 ORANGE  2016   November
# 2016-11-01                  Sangali             GREEN GRAM  2016   November
# 2016-11-01                  Sangali                  MATKI  2016   November
# 2016-11-01                  Sangali                 LENTIL  2016   November
# 2016-11-01                  Sangali             HORSE GRAM  2016   November
# 2016-11-01     Junnar (Narayangaon)             CORIANDER   2016   November
# 2016-11-01     Junnar (Narayangaon)           MATH (BHAJI)  2016   November
# 2016-11-01     Junnar (Narayangaon)                 TOMATO  2016   November
# 2016-11-01        Junnar (Alephata)            POMEGRANATE  2016   November
# 2016-11-01        Junnar (Alephata)          CUSTARD APPLE  2016   November
# 2016-11-01        Junnar (Alephata)                 POTATO  2016   November
# 2016-11-01        Junnar (Alephata)                  ONION  2016   November
# 2016-11-01  Sangli-Phale Bhajipalam                 POTATO  2016   November
# 2016-11-01           Junnar (Bhlhe)                BUFFALO  2016   November
# 2016-11-01                  Sangali                  BAJRI  2016   November
# 2016-11-01                  Sangali          WHEAT(HUSKED)  2016   November
# 2016-11-01                  Sangali          SORGUM(JAWAR)  2016   November
# 2016-11-01                  Sangali        WHEAT(UNHUSKED)  2016   November
# 2016-11-01                  Sangali                  MAIZE  2016   November
# 2016-11-01                  Sangali        RICE(PADDY-HUS)  2016   November
# 2016-11-01                  Sangali                   GRAM  2016   November
# 2016-11-01           Junnar (Bhlhe)              MALE GOAT  2016   November
# 2016-11-01                Shrigonda              SUNFLOWER  2016   November
#
#             arrivals_in_qtl  min_price  max_price  modal_price     date  \
# datetime
# 2014-09-01               64       2264       2571         2393  2014-09
# 2014-09-01                4       2560       2827         2827  2014-09
# 2014-09-01              135       1710       3455         1905  2014-09
# 2014-09-01              413       1092       1742         1417  2014-09
# 2014-09-01             2154       1632       2396         2050  2014-09
# 2014-09-01              388       1289       1615         1462  2014-09
# 2014-09-01             2638       1526       1776         1578  2014-09
# 2014-09-01              623       1247       1361         1336  2014-09
# 2014-09-01              171       1609       1777         1693  2014-09
# 2014-09-01              205       1392       2034         1709  2014-09
# 2014-09-01               12       1323       1362         1328  2014-09
# 2014-09-01                9       5900       6617         6234  2014-09
# 2014-09-01               31       3836       4128         4017  2014-09
# 2014-09-01              925       1954       3507         3431  2014-09
# 2014-09-01             1504        801       6010         4470  2014-09
# 2014-09-01           305620        323       1943         1360  2014-09
# 2014-09-01               74        567       1708         1137  2014-09
# 2014-09-01              542       2315       2828         2691  2014-09
# 2014-09-01             3470        255       2105         1705  2014-09
# 2014-09-01              348       1385       1457         1427  2014-09
# 2014-09-01              168       1783       1867         1825  2014-09
# 2014-09-01               80       1642       3358         2471  2014-09
# 2014-09-01              104       1396       3264         2544  2014-09
# 2014-09-01            56720        177       1618         1209  2014-09
# 2014-09-01              648       1304       1555         1453  2014-09
# 2014-09-01              137        871       3158         2054  2014-09
# 2014-09-01               54       1562       1635         1587  2014-09
# 2014-09-01               14       2297       2529         2494  2014-09
# 2014-09-01               78        910       1140         1025  2014-09
# 2014-09-01               49       3094       3667         3382  2014-09
# ...                     ...        ...        ...          ...      ...
# 2016-11-01              552       2306       4576         2869  2016-11
# 2016-11-01             1021       3615       6923         4231  2016-11
# 2016-11-01             2504       2800       7320         4700  2016-11
# 2016-11-01             1101         83        538          402  2016-11
# 2016-11-01              432       3059       6206         4294  2016-11
# 2016-11-01              415        243       1073          798  2016-11
# 2016-11-01             3228       4375       8889         5283  2016-11
# 2016-11-01             1582       1888       4281         2938  2016-11
# 2016-11-01             1201       5418       5994         5806  2016-11
# 2016-11-01             1604       5889       8778         7892  2016-11
# 2016-11-01              473       6092       6725         6575  2016-11
# 2016-11-01               12       3300       4200         3800  2016-11
# 2016-11-01           629140        251       1301         1175  2016-11
# 2016-11-01           223200        101        501          450  2016-11
# 2016-11-01            20612        205        659          558  2016-11
# 2016-11-01             7711       3300      10270         7870  2016-11
# 2016-11-01               14       2000       4000         3500  2016-11
# 2016-11-01               88        350        850          800  2016-11
# 2016-11-01            77440        590       1420         1245  2016-11
# 2016-11-01            26127        408       1512          940  2016-11
# 2016-11-01               91      15000      25000        22000  2016-11
# 2016-11-01             1937       1590       1808         1734  2016-11
# 2016-11-01            10523       1940       2869         2492  2016-11
# 2016-11-01            14301       1943       2873         2509  2016-11
# 2016-11-01              218       3491       3664         3603  2016-11
# 2016-11-01              604       1387       1440         1423  2016-11
# 2016-11-01            13575       2164       5586         4457  2016-11
# 2016-11-01              265       7606       8588         8329  2016-11
# 2016-11-01              561       3000       8000         7000  2016-11
# 2016-11-01               74       2933       3200         3067  2016-11
#
#            district_name   state_name   datetime
# datetime
# 2014-09-01      Buldhana  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01       Solapur  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# 2014-09-01         Nasik  Maharashtra 2014-09-01
# ...                  ...          ...        ...
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01        Sangli  Maharashtra 2016-11-01
# 2016-11-01          Pune  Maharashtra 2016-11-01
# 2016-11-01    Ahmadnagar  Maharashtra 2016-11-01
#
# [55951 rows x 12 columns]

# %%
data2.resample('M').sum().plot()

# %%
data.resample('M').sum().plot()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from numpy.polynomial.polynomial import polyfit
Y=data2.resample('M').sum()['arrivals_in_qtl']
X=np.array(range(1,810,30))
#X=X.reshape(-1,1)
print(Y.shape)
print(X.shape)
x = np.arange(10)
y = 5 * x + 10
#print(Y)
# regressor = linear_model.LinearRegression()
# regressor.fit(X,Y)
from scipy import stats
b, m = polyfit(X, Y, 1)

plt.plot(X, Y, '.')
plt.plot(X, b + m * X, '-')
plt.show()
# slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
# line = slope*X+intercept
# plt.scatter(X, Y,  color='black')
# plt.plot(X, Y, color='blue', linewidth=3)
# plt.plot(X,Y,'o', X, line)

# %%
print(data3.shape[0])
print(len(max_fluctuation_list))
# Out:
# 55951
# 9976

# %%
import statsmodels
data_ahm=data2_ahm.resample('M').mean()
result=statsmodels.tsa.tsatools.detrend(data_ahm_jflg['jflg'])   
result.plot()

# %%
trial_data=data2_ahm.copy()
trial_data=trial_data.set_index('date')
trial_data.index=trial_data['datetime']
#trial_data=trial_data.groupby('datetime')['jflg'].sum()
trial_data=trial_data.resample('M').sum()

# %%
trial_data=trial_data.dropna(how='any')
trial_data

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
APMC_dict.keys()
# Out:
# dict_keys(['Ahmednagar', 'Akole', 'Jamkhed', 'Kopargaon', 'Newasa', 'Newasa-Ghodegaon', 'Parner', 'Pathardi', 'Rahata', 'Rahuri', 'Rahuri-Vambori', 'Sangamner', 'Shevgaon', 'Shevgaon-Bodhegaon', 'Shrirampur', 'Shrirampur-Belapur', 'Shrigonda', 'Karjat (A- Nagar)', 'Rahuri-Songaon', 'Akola', 'Akot', 'Balapur', 'Murtizapur', 'Patur', 'Telhara', 'Barshi Takli', 'Achalpur', 'Amarawati', 'Amarawati-Fruit And Vegetables', 'Anajngaon Surji', 'Chandur Bajar', 'Chandur Rly.', 'Daryapur', 'Dhamangaon-Rly', 'Dharni', 'Morshi', 'Nandgaon Khandeshwar', 'Varud', 'Varud-Rajura Bazar', 'Tiwasa', 'Aurangabad', 'Fulambri', 'Gangapur', 'Kannad', 'Lasur Station', 'Paithan', 'Sillod', 'Sillod-Bharadi', 'Soygaon', 'Vaijapur', 'Khultabad', 'Ambejogai', 'Beed', 'Gevrai', 'Kada', 'Kada (Ashti)', 'Kej', 'Kille Dharur', 'Majalgaon', 'Parli-Vaijnath', 'Bhandara', 'Lakhandur', 'Lakhani', 'Pavani', 'Tumsar', 'Buldhana', 'Buldhana-Dhad', 'Chikhali', 'Deulgaon Raja', 'Jalgaon Jamod', 'Jalgaon Jamod-Aasalgaon', 'Khamgaon', 'Lonar', 'Malkapur', 'Mehkar', 'Nandura', 'Sangrampur', 'Sangrampur-Varvatbakal', 'Shegaon', 'Sindkhed Raja', 'Brahmpuri', 'Chandrapur', 'Chandrapur-Ganjwad', 'Chimur', 'Gondpimpri', 'Korpana', 'Mul', 'Nagbhid', 'Pombhurni', 'Rajura', 'Savali', 'Sindevahi', 'Varora', 'Bhadrawati', 'Dhule', 'Dondaicha', 'Dondaicha-Sindkheda', 'Sakri', 'Shirpur', 'Aheri', 'Armori', 'Armori-Desaiganj', 'Chamorshi', 'Gadchiroli', 'Sironcha', 'Aamgaon', 'Arjuni Morgaon', 'Gondiya', 'Sadak Arjuni', 'Tiroda', 'Goregaon', 'Devri', 'Akhadabalapur', 'Basmat', 'Hingoli', 'Jawala-Bajar', 'Kalamnuri', 'Sengaon', 'Basmat (Kurunda)', 'Hingoli-Kanegaon Naka', 'Amalner', 'Bhusaval', 'Bodwad-Varangaon', 'Chalisgaon', 'Chopda', 'Dharangaon', 'Jalgaon', 'Jalgaon-Masawat', 'Jamner', 'Jamner-Neri', 'Parola', 'Raver', 'Yawal', 'Pachora', 'Raver-Sawada', 'Ambad(Vadi Godri)', 'Bhokardan', 'Bhokardan-Pimpalgaon Renu', 'Ghansawangi', 'Jafrabad', 'Jalna', 'Jalna-Badnapur', 'Mantha', 'Partur', 'Ashti (Jalna)', 'Gadhinglaj', 'Kolhapur', 'Kolhapur-Laxmipuri', 'Kolhapur-Malkapur', 'Vadgaon Peth', 'Ahmedpur', 'Aurad Shahajani', 'Ausa', 'Chakur', 'Devani', 'Jalkot', 'Latur', 'Latur-Murud', 'Udgir', 'Nilanga', 'Mumbai', 'Mumbai-Fruit Market', 'Mumbai-Onion And Potato Mkt', 'Bhiwapur', 'Hingna', 'Kalmeshwar', 'Kamthi', 'Katol', 'Mandhal', 'Nagpur', 'Narkhed', 'Parshiwani', 'Ramtek', 'Savner', 'Umared', 'Mauda', 'Bhokar', 'Hadgaon', 'Hadgaon-Tamsa', 'Kinwat', 'Loha', 'Mahur', 'Nanded', 'Umari', 'Deglur', 'Naigaon', 'Dharmabad', 'Hanegaon', 'Himayatnagar', 'Kundalwadi', 'Mudkhed', 'Mukhed', 'Biloli', 'Kuntur', 'Akkalkuwa', 'Nandurbar', 'Navapur', 'Shahada', 'Taloda', 'Dhadgaon', 'Chandvad', 'Devala', 'Dindori', 'Dindori-Vani', 'Ghoti', 'Kalvan', 'Lasalgaon', 'Lasalgaon-Niphad', 'Lasalgaon-Vinchur', 'Malegaon', 'Manmad', 'Nampur', 'Nashik', 'Nashik-Devlali', 'Pimpalgaon (B)-Saykheda', 'Pimpalgaon Basawant', 'Satana', 'Sinner', 'Umrane', 'Yeola', 'Nandgaon', 'Kalamb (Os)', 'Murum', 'Osmanabad', 'Paranda', 'Tuljapur', 'Umarga', 'Lohara', 'Washi(Osmanabad)', 'Bhoom', 'Gangakhed', 'Jintur', 'Jintur-Bori', 'Palam', 'Parbhani', 'Pathari', 'Purna', 'Sailu', 'Sonpeth', 'Manwat', 'Bori', 'Tadkalas', 'Baramati', 'Dound', 'Indapur', 'Indapur (Nimgaon Ketki)', 'Indapur-Bhigwan', 'Junnar', 'Junnar (Alephata)', 'Junnar (Narayangaon)', 'Junnar-Otur', 'Khed (Shel Pimpalgaon)', 'Khed-Chakan', 'Manchar', 'Nira', 'Nira-Saswad', 'Pune', 'Pune-Manjri', 'Pune-Pimpri', 'Shirur', 'Junnar (Bhlhe)', 'Khed', 'Pune-Moshi', 'Bhor', 'Talegaon Dabhade', 'Alibag', 'Karjat (Raigad)', 'Mangaon(Bhadav)', 'Murud', 'Panvel', 'Pen', 'Roha', 'Khalapur(Shil-Phata)', 'Mahad', 'Ratanagari', 'Atpadi', 'Islampur', 'Sangali', 'Sangli-Miraj', 'Sangli-Phale Bhajipalam', 'Tasgaon', 'Palus', 'Vita', 'Shirala', 'Karad', 'Koregaon', 'Lonand', 'Patan', 'Phaltan', 'Satara', 'Vaduj', 'Vai', 'Akkolkot', 'Akluj', 'Barshi', 'Barshi-Vairag', 'Dudhani', 'Karmala', 'Kurdwadi', 'Kurdwadi-Modnimb', 'Mangalwedha', 'Mohol', 'Pandharpur', 'Sangola', 'Solapur' ...

# %%
def moving_average1(a, n=3, shape=28) :
    ret=np.zeros((len(range(0,shape,n))))
    i=0
    for x in range(0,shape,n):
        arr=a[x:x+n]
        ret[i]=np.mean(arr)
        i=i+1

    return ret

def moving_average2(ts, n=3):
    N = n
    cumsum, moving = [0], []
    for i, x in enumerate(ts, 1):
        cumsum.append(cumsum[i-1] + x)
        if i>=N:
            moving_ave = (cumsum[i] - cumsum[i-N])/N
            moving_avg.append(moving_ave)
    return moving_avg

# ts_log=np.log(time_data_)
# ts=time_data_
# moving_avg = pd.rolling_mean(ts_log,4)
# #plt.plot(ts_log)
# #plt.plot(moving_avg, color='red')
# MA=moving_average(ts_log.as_matrix(), n=4, shape=28)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
error_list=[]
deseasonalized_dict_add={}   #using imported function
deseasonalized_dict_mult={}
trial_methods_for_trend_1={} #using pandas rolling_mean
trial_methods_for_trend_2={} #using custom moving_average function

for APMC in APMC_dict.keys():
    try:
        APMC_pd=pd.DataFrame(data=APMC_dict[APMC], columns=['APMC', 'Commodity', 'Year', 'Month', 'arrivals_in_qtl', 'min_price',
       'max_price', 'modal_price', 'date', 'district_name', 'state_name'])
        APMC_pd['datetime'] = pd.to_datetime(APMC_pd['date'])
        APMC_pd.index=APMC_pd['datetime']
        del APMC_pd['datetime']
    
        idx = pd.date_range('2014-09-30', periods=APMC_pd.shape[0], freq='M')
        time_data_=pd.Series(APMC_dict[APMC][:,7], index=idx)
    #print(time_data_Aamgaon)
        time_data_=time_data_.fillna(time_data_.mean())
    #print(time_data_Aamgaon)
        print(APMC)
    
        decomposition = seasonal_decompose(time_data_, model='additive')

        trend = decomposition.trend
        seasonal = decomposition.seasonal
        residual = decomposition.resid
        deseasonalized_dict_add[APMC]={'trend':trend, 'seasonal':seasonal, 'residual':residual}
        
        decomposition = seasonal_decompose(time_data_, model='multiplicative')

        trend = decomposition.trend
        seasonal = decomposition.seasonal
        residual = decomposition.resid
        deseasonalized_dict_mult[APMC]={'trend':trend, 'seasonal':seasonal, 'residual':residual}
        
        ts_log=np.log(time_data_)
        ts=time_data_
        moving_avg_log = pd.rolling_mean(ts_log,4)
        moving_avg = pd.rolling_mean(ts,4)
#plt.plot(ts_log)
#plt.plot(moving_avg, color='red')
        MA_log=moving_average2(ts_log.as_matrix(), n=4, shape=28)
        MA=moving_average2(ts.as_matrix(), n=4, shape=28)
        
        trial_methods_for_trend_1[APMC]={'additive': moving_avg, 'multiplicative': moving_avg_log}
        trial_methods_for_trend_2[APMC]={'additive': MA, 'multiplicative': MA_log}
    except:
        error_list.append(APMC)

    #plt.subplot(411)
#     plt.figure()
#     plt.plot(ts_log, label='Original')
#     plt.legend(loc='best')
#     #plt.subplot(412)
#     plt.plot(trend, label='Trend')
#     plt.legend(loc='best')
#     #plt.subplot(413)
#     plt.plot(seasonal,label='Seasonality')
#     plt.legend(loc='best')
#     #plt.subplot(414)
#     plt.plot(residual, label='Residuals')
#     plt.legend(loc='best')
#     #plt.tight_layout()
#     plt.show()
#     plt.close()
#     decomposition = seasonal_decompose(time_data_, model='multiplicative')

#     trend = decomposition.trend
#     seasonal = decomposition.seasonal
#     residual = decomposition.resid
#     plt.figure()
#     #plt.subplot(411)
#     plt.plot(ts_log, label='Original')
#     plt.legend(loc='best')
#     #plt.subplot(412)
#     plt.plot(trend, label='Trend')
#     plt.legend(loc='best')
#     #plt.subplot(413)
#     plt.plot(seasonal,label='Seasonality')
#     plt.legend(loc='best')
#     #plt.subplot(414)
#     plt.plot(residual, label='Residuals')
#     plt.legend(loc='best')
#     #plt.tight_layout()
#     plt.show()
#     plt.close()
# Out:
# Ahmednagar
# Akole
# Jamkhed
# Kopargaon
# Newasa
# Newasa-Ghodegaon
# Parner
# Pathardi
# Rahata
# Rahuri
# Rahuri-Vambori
# Sangamner
# Shevgaon
# /home/glaedur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=4,center=False).mean()
# /home/glaedur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=4,center=False).mean()
# Shevgaon-Bodhegaon
# Shrirampur
# Shrirampur-Belapur
# Shrigonda
# Shrigonda-Ghogargaon
# Karjat (A- Nagar)
# Rahuri-Songaon
# Akola
# Akot
# Balapur
# Murtizapur
# Patur
# Telhara
# Barshi Takli
# Achalpur
# /home/glaedur/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# Amarawati
# Amarawati-Fruit And Vegetables
# Anajngaon Surji
# Chandur Bajar
# Chandur Rly.
# Daryapur
# Dhamangaon-Rly
# Dharni
# Morshi
# Nandgaon Khandeshwar
# Varud
# Varud-Rajura Bazar
# Tiwasa
# Aurangabad
# Fulambri
# Gangapur
# Kannad
# Lasur Station
# Paithan
# Sillod
# Sillod-Bharadi
# Soygaon
# Vaijapur
# Khultabad
# Ambejogai
# Beed
# Gevrai
# Kada
# Kada (Ashti)
# Kej
# Kille Dharur
# Majalgaon
# Parli-Vaijnath
# Bhandara
# Lakhandur
# Lakhani
# Pavani
# Tumsar
# Buldhana
# Buldhana-Dhad
# Chikhali
# Deulgaon Raja
# Jalgaon Jamod
# Jalgaon Jamod-Aasalgaon
# Khamgaon
# Lonar
# Malkapur
# Mehkar
# Nandura
# Sangrampur
# Sangrampur-Varvatbakal
# Shegaon
# Sindkhed Raja
# Brahmpuri
# Chandrapur
# Chandrapur-Ganjwad
# Chimur
# Gondpimpri
# Korpana
# Mul
# Nagbhid
# Pombhurni
# Rajura
# Savali
# Sindevahi
# Varora
# Bhadrawati
# Dhule
# Dondaicha
# Dondaicha-Sindkheda
# Sakri
# Shirpur
# Aheri
# Armori
# Armori-Desaiganj
# Chamorshi
# Gadchiroli
# Sironcha
# Aamgaon
# Arjuni Morgaon
# Gondiya
# Sadak Arjuni
# Tiroda
# Goregaon
# Devri
# Akhadabalapur
# Basmat
# Hingoli
# Jawala-Bajar
# Kalamnuri
# Sengaon
# Basmat (Kurunda)
# Hingoli-Kanegaon Naka
# Amalner
# Bhusaval
# Bodwad-Varangaon
# Chalisgaon
# Chopda
# Dharangaon
# Jalgaon
# Jalgaon-Masawat
# Jamner
# Jamner-Neri
# Parola
# Raver
# Yawal
# Pachora
# Raver-Sawada
# Ambad(Vadi Godri)
# Bhokardan
# Bhokardan-Pimpalgaon Renu
# Ghansawangi
# Jafrabad
# Jalna
# Jalna-Badnapur
# Mantha
# Partur
# Ashti (Jalna)
# Gadhinglaj
# Kolhapur
# Kolhapur-Laxmipuri
# Kolhapur-Malkapur
# Vadgaon Peth
# Ahmedpur
# Aurad Shahajani
# Ausa
# Chakur
# Devani
# Jalkot
# Latur
# Latur-Murud
# Udgir
# Nilanga
# Mumbai
# Mumbai-Fruit Market
# Mumbai-Onion And Potato Mkt
# Bhiwapur
# Hingna
# Kalmeshwar
# Kamthi
# Katol
# Mandhal
# Nagpur
# Narkhed
# Parshiwani
# Ramtek
# Savner
# Umared
# Mauda
# Bhokar
# Hadgaon
# Hadgaon-Tamsa
# Kinwat
# Loha
# Mahur
# Nanded
# Umari
# Deglur
# Naigaon
# Dharmabad
# Hanegaon
# Himayatnagar
# Kundalwadi
# Mudkhed
# Mukhed
# Biloli
# Kuntur
# Akkalkuwa
# Nandurbar
# Navapur
# Shahada
# Taloda
# Dhadgaon
# Chandvad
# Devala
# Dindori
# Dindori-Vani
# Ghoti
# Kalvan
# Lasalgaon
# Lasalgaon-Niphad
# Lasalgaon-Vinchur
# Malegaon
# Manmad
# Nampur
# Nashik
# Nashik-Devlali
# Pimpalgaon (B)-Saykheda
# Pimpalgaon Basawant
# Satana
# Sinner
# Umrane
# Yeola
# Nandgaon
# Kalamb (Os)
# Murum
# Osmanabad
# Paranda
# Tuljapur
# Umarga
# Lohara
# Washi(Osmanabad)
# Bhoom
# Gangakhed
# Jintur
# Jintur-Bori
# Palam
# Parbhani
# Pathari
# Purna
# Sailu
# Sonpeth
# Manwat
# Bori
# Tadkalas
# Baramati
# Dound
# Indapur
# Indapur (Nimgaon Ketki)
# Indapur-Bhigwan
# Junnar
# Junnar (Alephata)
# Junnar (Narayangaon)
# Junnar-Otur
# Khed (Shel Pimpalgaon)
# Khed-Chakan
# Manchar
# Nira
# Nira-Saswad
# Pune
# Pune-Manjri
# Pune-Pimpri
# Shirur
# Junnar (Bhlhe)
# Khed
# Pune-Moshi
# Bhor
# Talegaon Dabhade
# Alibag
# Karjat (Raigad)
# Mangaon(Bhadav)
# Murud
# Panvel
# Pen
# Roha
# Khalapur(Shil-Phata)
# Mahad
# Ratanagari
# Atpadi
# Islampur
# Sangali
# Sangli-Miraj
# Sangli-Phale Bhajipalam
# Tasgaon
# Palus
# Vita
# Shirala
# Karad
# Koregaon
# Lonand
# Patan
# Phaltan
# Satara
# Vaduj
# Vai
# Akkolkot
# Akluj
# Barshi
# Barshi-Vairag
# Dudhani
# Karmala
# Kurdwadi
# Kurdwadi-Modnimb
# Mangalwedha
# Mohol
# Pandharpur
# Sangola
# Solapur
# Bhivandi
# Kalyan
# Murbad
# Palghar(Bevur)
# Shahapur
# Ulhasnagar
# Vasai
# Kalyan (Cattle Market)
# Arvi
# Ashti (Wardha)
# Ashti-Karanja
# Hinganghat
# Pulgaon
# Samudrapur
# Sindi
# Sindi (Selu)
# Wardha
# Karanja
# Malegaon (Washim)
# Mangrulpeer
# Manora
# Risod
# Washim
# Washim-Ansing
# Aarni
# Babhulgaon
# Digras
# Ghatanji
# Kalamb (Yawatmal)
# Mahagaon
# Ner Parasopant
# Pandharkawada
# Pusad
# Ralegaon
# Umarkhed
# Umarkhed-Danki
# Vani
# Yeotmal
# Zarijamini
# Maregaon
# Bori Arab
# Darwha
# Vadvani

# %%
len(error_list)
# Out:
# 31

# %%
bajri=commodity_dict['BAJRI']
bajri_pd=pd.DataFrame(data=bajri, columns=['APMC', 'Commodity', 'Year', 'Month', 'arrivals_in_qtl', 'min_price',
       'max_price', 'modal_price', 'date', 'district_name', 'state_name'])

bajri_APMC_dict={}

for x in bajri_pd['APMC'].unique():
    bajri_APMC_dict[x]=np.zeros((1,bajri_pd.shape[1]))
    
for x in range(bajri_pd.shape[0]):
    bajri_APMC_dict[bajri[x][0]]=np.vstack((bajri_APMC_dict[bajri[x][0]], bajri[x]))
    
for x in bajri_APMC_dict.keys():
    bajri_APMC_dict[x]=np.delete(bajri_APMC_dict[x], 0, axis=0)

# %%
bajri_pd['datetime'] = pd.to_datetime(bajri_pd['date'])
bajri_pd.index=bajri_pd['datetime']
#bajri_pd=bajri_pd.resample('M').mean()

# %%
#plt.plot(moving_aves)
seasonal=ts_log[2:]-moving_aves
seasonal=seasonal.resample('Q').mean()
plt.plot(seasonal)

# %%
plt.plot(ts_log_moving_avg_diff)

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(2)
ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff)
# Out:
# /home/glaedur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """
# /home/glaedur/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  3.373384
# p-value                         1.000000
# #Lags Used                      9.000000
# Number of Observations Used    14.000000
# Critical Value (1%)            -4.012034
# Critical Value (5%)            -3.104184
# Critical Value (10%)           -2.690987
# dtype: float64

# %%
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)

# %%
from scipy import stats
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from numpy.polynomial.polynomial import polyfit
X=trend[6:19]
Y=ts_log[6:19]
b, m = polyfit(X, Y, 1)

plt.plot(X, Y, '.')
plt.plot(X, b + m * X, '-')
plt.show()

# %%
regressor = linear_model.LinearRegression()
X=trend[6:19]
Y=ts_log[6:19]
print(X.shape, Y.shape)
Y=Y.reshape(-1,1)
X=X.reshape(-1,1)
regressor.fit(X,Y)
y_pred=regressor.predict(X)
print("Mean squared error: %.2f"
      % mean_squared_error(Y, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y, y_pred))
plt.scatter(X, Y,  color='black')
plt.plot(X, y_pred, color='blue', linewidth=3)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(time_data_Aamgaon, model='additive')

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
commodities=data1['commodity'].unique()
data1=data1.dropna(how='any')
#print(data1.groupby('commodity', as_index=False).mean())
data300=(data1.groupby('commodity', as_index=False).mean()).as_matrix()
com_price={}
for x in range(32):
    com_price[data300[x][0]]=data300[x][2]   #com_price is dict with keys as commodities and values as their MSP

# %%
exceeding_msp=[] #list with entries exceeding MSP given in CMO_MSP_Mandi.csv
matrix2.shape

             
for x in range(matrix2.shape[0]):
    if matrix2[x][1].upper() in com_price.keys():
        if com_price[matrix2[x][1].upper()]>matrix2[x][5]:  #if minimum selling price <MSP, add the entry to the list
            exceeding_msp.append(matrix2[x])
len(exceeding_msp)
# Out:
# 6830

# %%
exceeding_msp
# Out:
# [array(['Kopargaon', 'BAJRI', 2015, 'April', 354, 1164, 1469, 1401,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2015, 'April', 9668, 1302, 1713,
#         1529, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'April', 672, 1070, 1421, 1324,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'April', 2038, 1445, 1974,
#         1770, '2016-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'April', 389, 1156, 1257, 1226,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2015, 'April', 25, 1550, 1550, 1550,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'April', 371, 1259, 1443, 1317,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'April', 734, 1528, 1783, 1648,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'April', 203, 1168, 1268, 1223, '2015-04',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2015, 'April', 2698, 1292, 1589, 1394,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'April', 589, 1123, 1315, 1217,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'April', 543, 1442, 1611, 1541,
#         '2016-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'April', 366, 1266, 1326, 1283, '2015-04',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'WHEAT(HUSKED)', 2015, 'April', 2403, 1402, 1498, 1450,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'WHEAT(HUSKED)', 2015, 'April', 2494, 1280, 1836,
#         1679, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'April', 830, 1255, 1500,
#         1377, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'April', 551, 1436, 1957,
#         1720, '2016-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'April', 54, 1275, 1278, 1276,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2015, 'April', 30, 2908, 2908, 2908,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'April', 216, 1219, 1325, 1267,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'WHEAT(HUSKED)', 2015, 'April', 1472, 1280, 1631, 1549,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'April', 1928, 1262, 1518, 1439,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'April', 887, 1087, 1225,
#         1156, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'April', 3503, 1382,
#         1501, 1439, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2015, 'April', 270, 1212, 1429, 1326,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'April', 5509, 1370, 1926,
#         1778, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'April', 1221, 1390, 1840,
#         1667, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2016, 'April', 1120, 1553, 1897,
#         1779, '2016-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'April', 323, 1122, 1209, 1168,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2015, 'April', 10, 3995, 4145,
#         4059, '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SAFFLOWER', 2015, 'April', 1, 2401, 2401, 2401,
#         '2015-04', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'August', 30, 1310, 1337, 1335,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'August', 303, 1518, 1721,
#         1641, '2016-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'August', 202, 1253, 1337, 1380,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'August', 201, 1550, 1728, 1612,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'August', 23, 1211, 1320, 1211, '2015-08',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2015, 'August', 478, 1406, 1498, 1444,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'August', 66, 1152, 1220, 1152,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'August', 98, 1474, 1474, 1474,
#         '2016-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'August', 167, 1377, 1504,
#         1450, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'August', 287, 1400, 1673,
#         1560, '2016-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'August', 13, 1278, 1308, 1293,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'August', 1510, 1383, 1718,
#         1718, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2015, 'August', 58, 1275, 1325, 1325,
#         '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'August', 520, 1425,
#         1526, 1526, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'August', 658, 1428, 1648,
#         1546, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'August', 187, 1558, 1808,
#         1698, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2016, 'August', 276, 1470, 1695,
#         1616, '2016-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'RICE(PADDY-HUS)', 2015, 'August', 4, 1172, 1172,
#         1172, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'WHEAT(HUSKED)', 2015, 'August', 62, 1267,
#         1433, 1350, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2016, 'August', 1, 1500,
#         1500, 1500, '2016-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2015, 'August', 29, 1200, 1300,
#         1250, '2015-08', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2014, 'December', 864, 1056, 1464, 1378,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2014, 'December', 864, 1427, 1678,
#         1568, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'December', 67, 1319, 1540,
#         1448, '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2014, 'December', 5159, 903, 1097, 1036,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2014, 'December', 330, 1260, 1492, 1361,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2014, 'December', 147, 1550, 2000,
#         1717, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2014, 'December', 112, 1151, 1273, 1206,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2014, 'December', 25, 1360, 1486, 1368,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'December', 139, 1421, 1458, 1431,
#         '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2014, 'December', 1316, 955, 1056, 985,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'SORGUM(JAWAR)', 2014, 'December', 15, 1444, 1444, 1444,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'December', 252, 1523,
#         1709, 1619, '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2014, 'December', 882, 1010, 1106, 1057,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'PIGEON PEA (TUR)', 2014, 'December', 57, 4309,
#         4440, 4428, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2014, 'December', 32, 2658, 2946,
#         2802, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2015, 'December', 11, 3399, 3399,
#         3399, '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2014, 'December', 599, 1143, 1435, 1368,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2014, 'December', 1047, 1124, 1345,
#         1266, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'MAIZE', 2014, 'December', 159, 960, 1045,
#         980, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2014, 'December', 455, 1162, 1456, 1320,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2014, 'December', 705, 1371, 1745,
#         1562, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2014, 'December', 149, 1535, 1947,
#         1800, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2014, 'December', 1234, 876, 1096, 987,
#         '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'RICE(PADDY-HUS)', 2014, 'December', 97, 1017, 1017,
#         1017, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2014, 'December', 12, 3733, 3733,
#         3733, '2014-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2015, 'December', 17, 1180,
#         1180, 1180, '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2015, 'December', 3203, 1117, 1283,
#         1200, '2015-12', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Akole', 'BAJRI', 2015, 'February', 4855, 1014, 1351, 1196,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Akole', 'PADDY-UNHUSKED', 2015, 'February', 5432, 936, 1335, 1108,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Akole', 'WHEAT(HUSKED)', 2015, 'February', 5130, 1076, 1401, 1258,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2015, 'February', 6169, 1065, 1477, 1411,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2015, 'February', 617, 1373, 1697,
#         1594, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'February', 1385, 1225, 1635,
#         1486, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'February', 7144, 1330, 1740,
#         1639, '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'February', 3134, 1096, 1190, 1166,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'PIGEON PEA (TUR)', 2015, 'February', 6, 4251, 4651,
#         4588, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'February', 280, 1252, 1400, 1304,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2016, 'February', 138, 1263, 1433, 1326,
#         '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'February', 741, 1515, 1775,
#         1627, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'February', 2898, 1200, 1514,
#         1374, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'February', 988, 1331, 1536, 1424,
#         '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'February', 1160, 1109, 1189, 1143,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'February', 1346, 1195,
#         1450, 1326, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'February', 869, 1384,
#         1750, 1588, '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'February', 302, 1105, 1161, 1129,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SAFFLOWER', 2015, 'February', 1, 2500, 2500,
#         2500, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2015, 'February', 1, 2751, 2751,
#         2751, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'COTTON', 2015, 'February', 86238, 3715, 3896, 3836,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'February', 536, 1246, 1366, 1318,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'February', 5281, 1234, 1667,
#         1588, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'February', 504, 1129, 1242,
#         1182, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'February', 6683,
#         1366, 1558, 1493, '2015-02', 'Ahmadnagar', 'Maharashtra'],
#        dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2016, 'February', 3768,
#         1526, 1638, 1638, '2016-02', 'Ahmadnagar', 'Maharashtra'],
#        dtype=object),
#  array(['Shevgaon-Bodhegaon', 'MAIZE', 2015, 'February', 18, 1050, 1150,
#         1025, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2015, 'February', 290, 1204, 1395, 1314,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'February', 524, 1401, 1758,
#         1625, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'February', 1026, 1405, 1763,
#         1649, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2016, 'February', 1462, 1496, 1769,
#         1646, '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'February', 362, 996, 1099, 1054,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2016, 'February', 537, 1249, 1345, 1297,
#         '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2015, 'February', 20, 4100, 4113,
#         4106, '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SUNFLOWER', 2015, 'February', 4, 2866, 3150, 2950,
#         '2015-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2016, 'February', 72, 1546,
#         1546, 1546, '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2016, 'February', 262, 1181, 1281,
#         1235, '2016-02', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Ahmednagar', 'MAIZE', 2015, 'January', 38, 1254, 1262, 1258,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2015, 'January', 622, 1091, 1507, 1400,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'January', 38, 1158, 1158,
#         1158, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'January', 660, 1274, 1483,
#         1432, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'January', 7178, 1042, 1185, 1135,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'COTTON', 2015, 'January', 6505, 3731, 3909, 3824,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'January', 218, 1261, 1413, 1314,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'January', 135, 1550, 1988,
#         1675, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'January', 28, 1429, 1452, 1429,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'January', 137, 1244, 1313, 1244,
#         '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'January', 950, 1061, 1126, 1086,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'January', 306, 1429,
#         1623, 1522, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'January', 471, 1105, 1152, 1129,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2015, 'January', 20, 2752, 2814,
#         2783, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2016, 'January', 49, 3394, 3434,
#         3415, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Sangamner', 'SORGUM(JAWAR)', 2015, 'January', 11, 1550, 1645,
#         1575, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'January', 842, 1141, 1492, 1439,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2016, 'January', 1642, 1523, 1765,
#         1763, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'January', 1250, 1150, 1357,
#         1285, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'January', 872, 1501,
#         1767, 1669, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'MAIZE', 2015, 'January', 129, 1011, 1044,
#         1033, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2015, 'January', 275, 1253, 1439, 1357,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'January', 645, 1427, 1772,
#         1600, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'January', 1136, 959, 1149, 1076,
#         '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2016, 'January', 362, 1283, 1375, 1333,
#         '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'RICE(PADDY-HUS)', 2015, 'January', 1, 1300, 1300,
#         1300, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2015, 'January', 8, 4075, 4275,
#         4175, '2015-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2016, 'January', 23, 1367,
#         1367, 1367, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2016, 'January', 247, 1204, 1289,
#         1250, '2016-01', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'July', 181, 1152, 1303, 1267,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'BAJRI', 2015, 'July', 2, 1250, 1250, 1250, '2015-07',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2015, 'July', 1, 1550, 1550, 1550,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'July', 289, 1253, 1447, 1341,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'July', 197, 1541, 1743, 1639,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'July', 118, 1187, 1264, 1212, '2015-07',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'July', 145, 1135, 1224, 1168,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'July', 157, 1464, 1554, 1514,
#         '2016-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'July', 174, 1198, 1335,
#         1269, '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'July', 278, 1219, 1362, 1362,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'July', 1351, 1307, 1546, 1546,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2015, 'July', 17, 1200, 1226, 1226, '2015-07',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'July', 288, 1158, 1212, 1207,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'July', 966, 1382,
#         1475, 1475, '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'July', 219, 1401, 1657, 1554,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'July', 20, 1264, 1294, 1279,
#         '2015-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2016, 'July', 1, 1500, 1500,
#         1500, '2016-07', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2015, 'June', 618, 1037, 1391, 1335,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2015, 'June', 2460, 1350, 1669, 1550,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'June', 354, 1172, 1500, 1415,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'June', 704, 1554, 1845, 1781,
#         '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'June', 399, 1138, 1215, 1195,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2015, 'June', 6, 1550, 1550, 1550,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'WHEAT(HUSKED)', 2015, 'June', 2392, 1372, 1752, 1765,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'June', 370, 1509, 1748, 1653,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'June', 196, 1205, 1286, 1223, '2015-06',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2015, 'June', 1317, 1365, 1515, 1432,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'June', 425, 1105, 1253, 1148,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'June', 171, 1443, 1575, 1509,
#         '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'June', 227, 1196, 1247, 1200, '2015-06',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'WHEAT(HUSKED)', 2015, 'June', 552, 1404, 1510, 1438,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'WHEAT(HUSKED)', 2016, 'June', 28, 1400, 1600, 1500,
#         '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Songaon', 'WHEAT(HUSKED)', 2016, 'June', 88, 1427, 1645,
#         1527, '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'WHEAT(HUSKED)', 2015, 'June', 1010, 1395, 1603,
#         1547, '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'June', 773, 1160, 1368,
#         1264, '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'June', 256, 1563, 1808,
#         1684, '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'June', 84, 1203, 1264, 1260,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'June', 552, 1143, 1303, 1288,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'WHEAT(HUSKED)', 2015, 'June', 1138, 1344, 1602, 1564,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'June', 1986, 1253, 1540, 1511,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2015, 'June', 26, 1026, 1101, 1101, '2015-06',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'June', 614, 1108, 1227, 1192,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'June', 2926, 1336,
#         1470, 1440, '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'June', 1505, 1420, 1722,
#         1596, '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'June', 648, 1405, 1731, 1627,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'June', 227, 1131, 1215, 1176,
#         '2015-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SAFFLOWER', 2016, 'June', 1, 2400, 2400, 2400,
#         '2016-06', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Ahmednagar', 'SORGUM(JAWAR)', 2015, 'March', 1949, 1560, 2100,
#         1830, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Ahmednagar', 'MAIZE', 2015, 'March', 20, 1000, 1225, 1112,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2015, 'March', 475, 1119, 1496, 1407,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2015, 'March', 8697, 1306, 1775,
#         1529, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'March', 2024, 1239, 1615,
#         1473, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'March', 2524, 1411, 1971,
#         1747, '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'March', 1024, 1153, 1241, 1207,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2015, 'March', 97, 1550, 1563, 1556,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'March', 346, 1260, 1407, 1311,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'March', 901, 1500, 1738, 1594,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'March', 148, 1234, 1326, 1253, '2015-03',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2015, 'March', 1778, 1309, 1476, 1380,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'March', 1331, 1194, 1503, 1381,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'March', 337, 1405, 1538, 1476,
#         '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'March', 914, 1217, 1262, 1225, '2015-03',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'WHEAT(HUSKED)', 2015, 'March', 1191, 1417, 1564, 1477,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'SORGUM(JAWAR)', 2015, 'March', 80, 1537, 1537, 1537,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'BAJRI', 2015, 'March', 79, 1212, 1343, 1286,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'WHEAT(HUSKED)', 2015, 'March', 1237, 1347, 1674,
#         1575, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'March', 914, 1314, 1648,
#         1478, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'March', 433, 1418, 1846,
#         1656, '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2015, 'March', 85, 1206, 1241, 1224,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2016, 'March', 1, 2700, 2700, 2700,
#         '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'COTTON', 2015, 'March', 18396, 3617, 3877, 3808,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'WHEAT(HUSKED)', 2015, 'March', 1677, 1293, 1531, 1422,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'March', 2919, 1300, 1623, 1559,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'March', 490, 1072, 1217,
#         1153, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'March', 6217, 1348,
#         1514, 1448, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2015, 'March', 293, 1228, 1448, 1366,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'March', 1942, 1365, 1799,
#         1584, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'March', 2073, 1362, 1864,
#         1668, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2016, 'March', 1324, 1524, 1835,
#         1711, '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'March', 105, 1111, 1172, 1151,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2016, 'March', 287, 1286, 1350, 1308,
#         '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2015, 'March', 13, 4006, 4209,
#         4083, '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SAFFLOWER', 2015, 'March', 2, 2601, 2601, 2601,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MUSTARD', 2015, 'March', 23, 2961, 3167, 3089,
#         '2015-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2016, 'March', 7, 1375,
#         1375, 1375, '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2016, 'March', 154, 1214, 1241,
#         1232, '2016-03', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Akole', 'WHEAT(HUSKED)', 2015, 'May', 163, 1425, 2000, 1625,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2015, 'May', 747, 1086, 1417, 1358,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2015, 'May', 4218, 1322, 1641, 1479,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'May', 609, 1058, 1396, 1328,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'May', 1484, 1558, 1823, 1750,
#         '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'May', 813, 1112, 1221, 1199,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2015, 'May', 12, 1550, 1550, 1550,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'May', 318, 1260, 1492, 1333, '2015-05',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'May', 424, 1533, 1667, 1589,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'May', 143, 1133, 1308, 1176, '2015-05',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2015, 'May', 1238, 1311, 1505, 1403,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'May', 243, 1078, 1213, 1121,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'May', 361, 1477, 1588, 1497,
#         '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'May', 398, 1204, 1273, 1228, '2015-05',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'WHEAT(HUSKED)', 2015, 'May', 1517, 1400, 1463, 1432,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'SORGUM(JAWAR)', 2015, 'May', 23, 1550, 1550, 1550,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Songaon', 'WHEAT(HUSKED)', 2016, 'May', 28, 1413, 1595,
#         1469, '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'WHEAT(HUSKED)', 2015, 'May', 262, 1330, 1743,
#         1603, '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'May', 140, 1164, 1354,
#         1263, '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2015, 'May', 15, 3000, 3000, 3000,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2016, 'May', 1, 3300, 3300, 3300,
#         '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'May', 260, 1188, 1300, 1265, '2015-05',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'WHEAT(HUSKED)', 2015, 'May', 1198, 1359, 1619, 1524,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'May', 1915, 1179, 1545, 1490,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2015, 'May', 14, 1250, 1250, 1250, '2015-05',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2015, 'May', 885, 1064, 1202, 1131,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'May', 2782, 1311,
#         1440, 1370, '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'May', 2345, 1416, 1774, 1664,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'May', 843, 1418, 1834, 1722,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'May', 472, 1113, 1193, 1148,
#         '2015-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SAFFLOWER', 2016, 'May', 3, 2330, 2450, 2400,
#         '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2016, 'May', 11, 1225, 1225, 1225,
#         '2016-05', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Ahmednagar', 'PIGEON PEA (TUR)', 2014, 'November', 100, 4140,
#         4440, 4290, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2014, 'November', 1167, 1224, 1503, 1429,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2014, 'November', 39, 1260, 1775,
#         1476, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'November', 39, 1309, 1681,
#         1547, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2014, 'November', 768, 977, 1124, 1069,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2014, 'November', 628, 1255, 1475, 1346,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2014, 'November', 164, 1540, 2120,
#         1750, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'November', 298, 1559, 1871,
#         1685, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'November', 67, 1250, 1325, 1250,
#         '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2014, 'November', 71, 1410, 1462, 1442,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'November', 85, 1221, 1254, 1225,
#         '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2014, 'November', 296, 1076, 1169, 1107,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'November', 1663, 1202, 1352, 1292,
#         '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'PIGEON PEA (TUR)', 2014, 'November', 1, 3050, 3050,
#         3050, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'November', 36, 1563,
#         1851, 1707, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2014, 'November', 270, 1094, 1203, 1171,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'PIGEON PEA (TUR)', 2014, 'November', 9, 4200,
#         4200, 4200, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2014, 'November', 30, 2868, 2892,
#         2880, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2014, 'November', 1224, 1165, 1452, 1346,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2014, 'November', 35, 1000, 1000, 1000,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2014, 'November', 1035,
#         1548, 1915, 1739, '2014-11', 'Ahmadnagar', 'Maharashtra'],
#        dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'November', 1851,
#         1558, 1710, 1710, '2015-11', 'Ahmadnagar', 'Maharashtra'],
#        dtype=object),
#  array(['Shrirampur', 'BAJRI', 2014, 'November', 349, 1267, 1564, 1441,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2014, 'November', 739, 1374, 1866,
#         1576, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'November', 183, 1495, 1876,
#         1755, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2014, 'November', 244, 1121, 1322, 1177,
#         '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'November', 273, 1213, 1301, 1262,
#         '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'PIGEON PEA (TUR)', 2014, 'November', 2, 3000, 4100,
#         3500, '2014-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'BAJRI', 2015, 'November', 3, 1200, 1200,
#         1200, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'WHEAT(HUSKED)', 2015, 'November', 473, 1385,
#         1595, 2163, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'SORGUM(JAWAR)', 2015, 'November', 17, 1050,
#         1100, 1075, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur-Belapur', 'MAIZE', 2015, 'November', 780, 1056, 1256,
#         1156, '2015-11', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Ahmednagar', 'BAJRI', 2016, 'October', 1219, 1254, 1560, 1415,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2014, 'October', 644, 1204, 1451, 1363,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'BAJRI', 2016, 'October', 2649, 1209, 1515, 1391,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'WHEAT(HUSKED)', 2014, 'October', 828, 1349, 1584,
#         1488, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2014, 'October', 2, 1400, 1400, 1400,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2015, 'October', 153, 1157, 1389,
#         1339, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'SORGUM(JAWAR)', 2016, 'October', 476, 1444, 1673,
#         1596, '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2014, 'October', 42, 1117, 1117, 1117,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Kopargaon', 'MAIZE', 2015, 'October', 987, 1216, 1351, 1320,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Newasa', 'SORGUM(JAWAR)', 2014, 'October', 3, 1550, 1550, 1550,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'BAJRI', 2015, 'October', 452, 1253, 1480, 1361,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2014, 'October', 473, 1535, 1900,
#         1681, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Pathardi', 'SORGUM(JAWAR)', 2015, 'October', 533, 1547, 1763,
#         1641, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2015, 'October', 175, 1125, 1244, 1150,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'BAJRI', 2016, 'October', 1097, 1121, 1356, 1205,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'WHEAT(HUSKED)', 2014, 'October', 309, 1420, 1557, 1470,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2014, 'October', 18, 1088, 1375, 1263,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2015, 'October', 191, 1158, 1258, 1183,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'SORGUM(JAWAR)', 2016, 'October', 109, 1293, 1413, 1308,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2014, 'October', 288, 900, 900, 900, '2014-10',
#         'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2015, 'October', 407, 1231, 1314, 1253,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahata', 'MAIZE', 2016, 'October', 402, 1086, 1170, 1118,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri', 'SORGUM(JAWAR)', 2014, 'October', 8, 1488, 1550, 1525,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'BAJRI', 2016, 'October', 3659, 1136, 1567, 1486,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2015, 'October', 376, 1333,
#         1536, 1442, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SORGUM(JAWAR)', 2016, 'October', 202, 1449,
#         1790, 1641, '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'MAIZE', 2014, 'October', 87, 1118, 1144, 1131,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'PIGEON PEA (TUR)', 2014, 'October', 2, 3748,
#         3748, 3748, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2014, 'October', 6, 2865, 2865,
#         2865, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Rahuri-Vambori', 'SUNFLOWER', 2016, 'October', 20, 2000, 2890,
#         2445, '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Sangamner', 'SORGUM(JAWAR)', 2014, 'October', 34, 1538, 1788,
#         1663, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2014, 'October', 497, 1124, 1348, 1271,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2015, 'October', 563, 1214, 1414, 1414,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'BAJRI', 2016, 'October', 2815, 1017, 1220, 1220,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'WHEAT(HUSKED)', 2014, 'October', 794, 1405, 1576,
#         1461, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2014, 'October', 602, 1380, 1744,
#         1654, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'SORGUM(JAWAR)', 2015, 'October', 1994, 1347, 1543,
#         1543, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon', 'MAIZE', 2016, 'October', 8, 1150, 1150, 1150,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2014, 'October', 1324, 1180, 1281,
#         1237, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'BAJRI', 2016, 'October', 2090, 995, 1370,
#         1370, '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2014, 'October', 726, 1462,
#         1736, 1596, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shevgaon-Bodhegaon', 'SORGUM(JAWAR)', 2015, 'October', 2171, 1435,
#         1561, 1561, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'BAJRI', 2016, 'October', 810, 1227, 1495, 1400,
#         '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2014, 'October', 935, 1408, 1691,
#         1544, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'WHEAT(HUSKED)', 2015, 'October', 1149, 1416, 1755,
#         1624, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2014, 'October', 208, 1456, 1731,
#         1612, '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2015, 'October', 330, 1448, 1713,
#         1614, '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'SORGUM(JAWAR)', 2016, 'October', 187, 1525, 1688,
#         1592, '2016-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2014, 'October', 21, 1252, 1267, 1259,
#         '2014-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
#  array(['Shrirampur', 'MAIZE', 2015, 'October', 325, 1221, 1263, 1241,
#         '2015-10', 'Ahmadnagar', 'Maharashtra'], dtype=object),
# ...
#  array(['Morshi', 'SORGUM(JAWAR)', 2014, 'November', 1273, 1364, 1475,
#         1420, '2014-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2015, 'November', 1817, 1200, 1275,
#         1218, '2015-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Nandgaon Khandeshwar', 'WHEAT(HUSKED)', 2015, 'November', 72,
#         1028, 1425, 1226, '2015-11', 'Amaravathi', 'Maharashtra'],
#        dtype=object),
#  array(['Varud', 'COTTON', 2015, 'November', 5848, 3716, 4084, 4013,
#         '2015-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'WHEAT(HUSKED)', 2014, 'November', 52, 1397,
#         1469, 1433, '2014-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2014, 'November', 5, 1401,
#         1585, 1568, '2014-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2015, 'November', 20, 1251,
#         1276, 1267, '2015-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'MAIZE', 2015, 'November', 2, 1271, 1271,
#         1271, '2015-11', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'PIGEON PEA (TUR)', 2014, 'November', 21,
#         3533, 5033, 4159, '2014-11', 'Amaravathi', 'Maharashtra'],
#        dtype=object),
#  array(['Achalpur', 'SORGUM(JAWAR)', 2014, 'October', 5, 1530, 1550, 1540,
#         '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'SORGUM(JAWAR)', 2015, 'October', 57, 1503, 1800,
#         1587, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'MAIZE', 2015, 'October', 1303, 1150, 1250, 1175,
#         '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'WHEAT(HUSKED)', 2014, 'October', 780, 1393,
#         1514, 1454, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'WHEAT(HUSKED)', 2015, 'October', 841, 1380,
#         1711, 1493, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'WHEAT(HUSKED)', 2016, 'October', 370, 1429,
#         1882, 1618, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2014, 'October', 72, 1375,
#         1442, 1404, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2015, 'October', 2170, 1113,
#         1336, 1197, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2016, 'October', 635, 986,
#         1536, 1321, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'WHEAT(HUSKED)', 2014, 'October', 96, 1400, 1800,
#         1600, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'WHEAT(HUSKED)', 2015, 'October', 827, 1408, 1617,
#         1494, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'SORGUM(JAWAR)', 2014, 'October', 132, 1352, 1500,
#         1450, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'SORGUM(JAWAR)', 2015, 'October', 639, 1227, 1418,
#         1322, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'SORGUM(JAWAR)', 2016, 'October', 287, 1305, 1503,
#         1408, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Daryapur', 'SORGUM(JAWAR)', 2015, 'October', 948, 1148, 1407,
#         1275, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Dhamangaon-Rly', 'WHEAT(HUSKED)', 2014, 'October', 1910, 1321,
#         1487, 1378, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Dharni', 'SORGUM(JAWAR)', 2016, 'October', 3010, 1371, 1443, 1407,
#         '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Dharni', 'MAIZE', 2016, 'October', 1175, 1264, 1336, 1300,
#         '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'WHEAT(HUSKED)', 2014, 'October', 598, 1367, 1508, 1438,
#         '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2014, 'October', 49, 1400, 1500, 1450,
#         '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2015, 'October', 983, 1094, 1163, 1116,
#         '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2016, 'October', 472, 1394, 1509, 1458,
#         '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Nandgaon Khandeshwar', 'WHEAT(HUSKED)', 2015, 'October', 915,
#         1160, 1445, 1303, '2015-10', 'Amaravathi', 'Maharashtra'],
#        dtype=object),
#  array(['Nandgaon Khandeshwar', 'SORGUM(JAWAR)', 2016, 'October', 5, 851,
#         851, 851, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud', 'SORGUM(JAWAR)', 2016, 'October', 3646, 14, 30, 30,
#         '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud', 'MAIZE', 2016, 'October', 2784, 25, 50, 50, '2016-10',
#         'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'WHEAT(HUSKED)', 2014, 'October', 115, 1415,
#         1454, 1439, '2014-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2015, 'October', 65, 1170,
#         1190, 1186, '2015-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2016, 'October', 4064, 576,
#         651, 601, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'MAIZE', 2016, 'October', 15, 1216, 1475,
#         1271, '2016-10', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'SORGUM(JAWAR)', 2014, 'September', 16, 1475, 1788,
#         1613, '2014-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'SORGUM(JAWAR)', 2015, 'September', 51, 1509, 1837,
#         1608, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'MAIZE', 2015, 'September', 51, 1150, 1250, 1172,
#         '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Amarawati', 'SUNFLOWER', 2015, 'September', 18, 2742, 2913, 2781,
#         '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'WHEAT(HUSKED)', 2014, 'September', 1434, 1398,
#         1598, 1498, '2014-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'WHEAT(HUSKED)', 2015, 'September', 1217, 1328,
#         1650, 1466, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2014, 'September', 132, 1327,
#         1531, 1437, '2014-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2015, 'September', 60, 1286,
#         1452, 1325, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Anajngaon Surji', 'SORGUM(JAWAR)', 2016, 'September', 64, 1250,
#         1579, 1421, '2016-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'WHEAT(HUSKED)', 2015, 'September', 823, 1400,
#         1600, 1447, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Chandur Bajar', 'SORGUM(JAWAR)', 2016, 'September', 46, 1350,
#         1500, 1438, '2016-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Daryapur', 'SORGUM(JAWAR)', 2015, 'September', 12, 1501, 1501,
#         1501, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Dharni', 'SORGUM(JAWAR)', 2016, 'September', 985, 1564, 1664,
#         1614, '2016-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'WHEAT(HUSKED)', 2015, 'September', 912, 1431, 1525,
#         1460, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2014, 'September', 49, 1400, 1500, 1450,
#         '2014-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2015, 'September', 454, 1100, 1168,
#         1120, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Morshi', 'SORGUM(JAWAR)', 2016, 'September', 385, 1375, 1463,
#         1428, '2016-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Nandgaon Khandeshwar', 'WHEAT(HUSKED)', 2015, 'September', 1854,
#         1161, 1501, 1331, '2015-09', 'Amaravathi', 'Maharashtra'],
#        dtype=object),
#  array(['Varud-Rajura Bazar', 'WHEAT(HUSKED)', 2014, 'September', 93, 1331,
#         1503, 1430, '2014-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'WHEAT(HUSKED)', 2015, 'September', 66, 1422,
#         1482, 1449, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2015, 'September', 31, 1243,
#         1293, 1263, '2015-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'SORGUM(JAWAR)', 2016, 'September', 11, 1463,
#         1477, 1471, '2016-09', 'Amaravathi', 'Maharashtra'], dtype=object),
#  array(['Varud-Rajura Bazar', 'PIGEON PEA (TUR)', 2014, 'September', 24,
#         3840, 4750, 4214, '2014-09', 'Amaravathi', 'Maharashtra'],
#        dtype=object),
#  array(['Gangapur', 'BAJRI', 2015, 'April', 324, 1179, 1398, 1279,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'WHEAT(HUSKED)', 2015, 'April', 2062, 1344, 1902, 1616,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'SORGUM(JAWAR)', 2015, 'April', 998, 1339, 1783, 1542,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'MAIZE', 2015, 'April', 90, 1216, 1268, 1244,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'BAJRI', 2015, 'April', 357, 1204, 1412, 1342, '2015-04',
#         'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'WHEAT(HUSKED)', 2015, 'April', 1112, 1373, 1665, 1606,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'SORGUM(JAWAR)', 2015, 'April', 51, 1422, 1623, 1549,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'SORGUM(JAWAR)', 2016, 'April', 30, 1560, 1754, 1685,
#         '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'MAIZE', 2015, 'April', 7609, 1102, 1251, 1207,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'MAIZE', 2016, 'April', 3076, 1195, 1332, 1279,
#         '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'BAJRI', 2015, 'April', 1123, 1153, 1417, 1292,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'WHEAT(HUSKED)', 2015, 'April', 3972, 1279, 1988,
#         1577, '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'SORGUM(JAWAR)', 2015, 'April', 6895, 1168, 2198,
#         1708, '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'SORGUM(JAWAR)', 2016, 'April', 5788, 1490, 2349,
#         1879, '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'MAIZE', 2015, 'April', 2579, 1155, 1255, 1224,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'SAFFLOWER', 2015, 'April', 15, 2434, 2767, 2501,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Paithan', 'BAJRI', 2015, 'April', 3801, 653, 653, 651, '2015-04',
#         'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Paithan', 'WHEAT(HUSKED)', 2015, 'April', 4726, 716, 868, 823,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Paithan', 'SORGUM(JAWAR)', 2015, 'April', 4606, 790, 836, 800,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Paithan', 'PIGEON PEA (TUR)', 2015, 'April', 14500, 4, 5, 5,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'SORGUM(JAWAR)', 2016, 'April', 40, 1250, 1350, 1300,
#         '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'SAFFLOWER', 2016, 'April', 5, 3000, 3200, 3100,
#         '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Soygaon', 'MAIZE', 2015, 'April', 1372, 1007, 1150, 1077,
#         '2015-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Vaijapur', 'SAFFLOWER', 2016, 'April', 3, 2850, 2850, 2850,
#         '2016-04', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'SORGUM(JAWAR)', 2015, 'August', 155, 1420, 1662, 1510,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'BAJRI', 2015, 'August', 131, 1143, 1329, 1317,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'SORGUM(JAWAR)', 2015, 'August', 16, 1460, 1460, 1460,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'PIGEON PEA (TUR)', 2015, 'August', 1, 3000, 3000, 3000,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'SORGUM(JAWAR)', 2015, 'August', 1792, 1296, 2002,
#         1712, '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Lasur Station', 'SORGUM(JAWAR)', 2016, 'August', 1947, 1551, 1921,
#         1721, '2016-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'BAJRI', 2015, 'August', 303, 1140, 1263, 1202,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'WHEAT(HUSKED)', 2015, 'August', 854, 1272, 1500, 1431,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'SORGUM(JAWAR)', 2015, 'August', 25, 1075, 1200, 1163,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod', 'SORGUM(JAWAR)', 2016, 'August', 16, 1423, 1540, 1500,
#         '2016-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod-Bharadi', 'BAJRI', 2015, 'August', 20, 1175, 1175, 1175,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod-Bharadi', 'SORGUM(JAWAR)', 2015, 'August', 2, 1125, 1125,
#         1125, '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod-Bharadi', 'SORGUM(JAWAR)', 2016, 'August', 9, 1383, 1450,
#         1437, '2016-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod-Bharadi', 'SAFFLOWER', 2015, 'August', 4, 2171, 2171, 2171,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Sillod-Bharadi', 'SAFFLOWER', 2016, 'August', 1, 2375, 2375, 2375,
#         '2016-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Soygaon', 'MAIZE', 2015, 'August', 114, 1100, 1250, 1200,
#         '2015-08', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Aurangabad', 'MAIZE', 2014, 'December', 18009, 858, 1071, 965,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Fulambri', 'WHEAT(HUSKED)', 2015, 'December', 90, 1400, 1500,
#         1450, '2015-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Fulambri', 'MAIZE', 2014, 'December', 98, 870, 950, 899,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Fulambri', 'MAIZE', 2015, 'December', 999, 1205, 1310, 1258,
#         '2015-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'BAJRI', 2014, 'December', 310, 1198, 1426, 1320,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'SORGUM(JAWAR)', 2014, 'December', 167, 1456, 1756,
#         1604, '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'SORGUM(JAWAR)', 2015, 'December', 224, 1497, 1715,
#         1611, '2015-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Gangapur', 'MAIZE', 2014, 'December', 5544, 846, 997, 910,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'BAJRI', 2014, 'December', 181, 1250, 1364, 1302,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'SORGUM(JAWAR)', 2014, 'December', 3, 1375, 1375, 1375,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  array(['Kannad', 'MAIZE', 2014, 'December', 32198, 839, 975, 923,
#         '2014-12', 'Aurangabad', 'Maharashtra'], dtype=object),
#  ...]

# %%
com_price
# Out:
# {'BAJRI': 1268.0,
#  'BARLI': 1113.75,
#  'COCONUT': 1470.0,
#  'COTTON': 3742.0,
#  'Copra (Ball)_Yellow': 5684.0,
#  'Copra (Milling)_Yellow': 5420.0,
#  'Cotton_Long Staple': 4042.0,
#  'GR.NUT KERNELS': 3970.0,
#  'Gram_Yellow': 3175.0,
#  'Jowar_Hybrid': 1545.0,
#  'Jute_Yellow': 2560.0,
#  'MAIZE': 1297.0,
#  'MUSTARD': 3125.0,
#  'Masur_Yellow': 3062.5,
#  'NIGER-SEED': 3595.0,
#  'PADDY-UNHUSKED': 1360.0,
#  'PIGEON PEA (TUR)': 4310.0,
#  'RICE(PADDY-HUS)': 1397.0,
#  'Ragi_Maldandi': 1585.0,
#  'SAFFLOWER': 3037.5,
#  'SESAMUM': 4560.0,
#  'SORGUM(JAWAR)': 1566.0,
#  'SOYABEAN': 2527.0,
#  'SPILT GERRN GRAM': 4590.0,
#  'SPLIT BLACK GRAM': 4390.0,
#  'SUGAR-CANE': 207.5,
#  'SUGARCANE': 230.0,
#  'SUNFLOWER': 3760.0,
#  'Soyabean_Black': 2400.0,
#  'Toria_Yellow': 3075.0,
#  'WHEAT(HUSKED)': 1431.25,
#  'WHEAT(UNHUSKED)': 1431.25}

# %%
data3=data2.copy()       #storing fluctuation (max_price - min_price) in a column of data3,
                         #sorted in descending order of fluctuation
data3['fluctuation']=data3['max_price']-data3['min_price']
data3=data3.sort_values(by=['fluctuation'], ascending=False)
data3_mat=data3.as_matrix() 
data3.head()
# Out:
#                           APMC   Commodity  Year     Month  arrivals_in_qtl  \
# 46972                   Atpadi       GOATS  2016     April              354
# 26989                   Mumbai  CASHEWNUTS  2015   October             7756
# 27006                   Mumbai    CARDAMOM  2016   October              788
# 47276  Sangli-Phale Bhajipalam       MANGO  2016  February               78
# 62381                   Mumbai    CARDAMOM  2016  November              564
#
#        min_price  max_price  modal_price     date district_name   state_name  \
# 46972       4000    1600090        10000  2016-04        Sangli  Maharashtra
# 26989      70000     140000       105000  2015-10        Mumbai  Maharashtra
# 27006      86471     152941       119706  2016-10        Mumbai  Maharashtra
# 47276      17422      83075        43218  2016-02        Sangli  Maharashtra
# 62381     110313     174375       142344  2016-11        Mumbai  Maharashtra
#
#        fluctuation
# 46972      1596090
# 26989        70000
# 27006        66470
# 47276        65653
# 62381        64062

# %%
APMCs=data2['APMC'].unique()
max_fluctuation_list=[]
#data2['Commodity']=data2['Commodity'].str.upper()
# for x in range(APMCs.shape[0]):
#     pass
APMC_com=data2['Commodity'].unique()

check_arr=np.zeros((APMCs.shape[0], APMC_com.shape[0], 3)) #array of size no. of APMCs * no. of commodities * no. of years

for x in range(data3.shape[0]):
    if(check_arr[np.where(APMCs==(data3_mat[x][0]))[0][0]][np.where(APMC_com==(data3_mat[x][1]))[0][0]][data3_mat[x][2]-2014]==0):
        max_fluctuation_list.append(data3_mat[x])
        check_arr[np.where(APMCs==(data3_mat[x][0]))[0][0]][np.where(APMC_com==(data3_mat[x][1]))[0][0]][data3_mat[x][2]-2014]=1

# passing through data3, the first occurence of commodity in an APMC in a year in data3 will have the maximum fluctuation
#as data3 is sorted in descending order of fluctuation. First occurence marks check_arr as 1 and no other values of the
# APMC*commodity*year is added to the max_fluctuation_list
